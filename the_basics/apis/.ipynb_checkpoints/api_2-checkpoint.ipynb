# %% [markdown]
# # Python For Finance 2
#
# [More about this](https://github.com/yhilpisch/py4fi/blob/master/jupyter36/06_Financial_Time_Series.ipynb)

# %% [markdown]
# <img src="media/yahoo.jpeg" width="600">

# %% [markdown]
# # yahoofinancials
#
# A powerful financial data module used for pulling fundamental and technical stock data from Yahoo Finance

# %%
from yahoofinancials import YahooFinancials

# %%
import pandas as pd
from pandas.io.json import json_normalize
import seaborn as sns
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
import plotly.offline as plyo
import chart_studio.plotly as py
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
#from plotly.graph_objs import FigureWidget

# %%
#import cufflinks as cf

# %%
ticker = 'AAPL'
yahoo_financials = YahooFinancials(ticker)

yahoo_financials

# %% [markdown]
# ## Extracting Company Information
# I extracted a lot of material to work with!! This might take a couple of minutes to load.

# %%
historical_stock_prices = yahoo_financials.get_historical_price_data('2015-09-15', '2019-10-24', 'daily')

# %%
historical_stock_prices
# Out:
# {'AAPL': {'eventsData': {'dividends': {'2016-11-03': {'amount': 0.57,
#      'date': 1478179800,
#      'formatted_date': '2016-11-03'},
#     '2017-05-11': {'amount': 0.63,
#      'date': 1494509400,
#      'formatted_date': '2017-05-11'},
#     '2018-11-08': {'amount': 0.73,
#      'date': 1541687400,
#      'formatted_date': '2018-11-08'},
#     '2017-11-10': {'amount': 0.63,
#      'date': 1510324200,
#      'formatted_date': '2017-11-10'},
#     '2018-05-11': {'amount': 0.73,
#      'date': 1526045400,
#      'formatted_date': '2018-05-11'},
#     '2019-05-10': {'amount': 0.77,
#      'date': 1557495000,
#      'formatted_date': '2019-05-10'},
#     '2015-11-05': {'amount': 0.52,
#      'date': 1446733800,
#      'formatted_date': '2015-11-05'},
#     '2016-05-05': {'amount': 0.57,
#      'date': 1462455000,
#      'formatted_date': '2016-05-05'},
#     '2017-02-09': {'amount': 0.57,
#      'date': 1486650600,
#      'formatted_date': '2017-02-09'},
#     '2017-08-10': {'amount': 0.63,
#      'date': 1502371800,
#      'formatted_date': '2017-08-10'},
#     '2018-02-09': {'amount': 0.63,
#      'date': 1518186600,
#      'formatted_date': '2018-02-09'},
#     '2018-08-10': {'amount': 0.73,
#      'date': 1533907800,
#      'formatted_date': '2018-08-10'},
#     '2019-02-08': {'amount': 0.73,
#      'date': 1549636200,
#      'formatted_date': '2019-02-08'},
#     '2019-08-09': {'amount': 0.77,
#      'date': 1565357400,
#      'formatted_date': '2019-08-09'},
#     '2016-02-04': {'amount': 0.52,
#      'date': 1454596200,
#      'formatted_date': '2016-02-04'},
#     '2016-08-04': {'amount': 0.57,
#      'date': 1470317400,
#      'formatted_date': '2016-08-04'}}},
#   'firstTradeDate': {'formatted_date': '1980-12-12', 'date': 345459600},
#   'currency': 'USD',
#   'instrumentType': 'EQUITY',
#   'timeZone': {'gmtOffset': -14400},
#   'prices': [{'date': 1442323800,
#     'high': 116.52999877929688,
#     'low': 114.41999816894531,
#     'open': 115.93000030517578,
#     'close': 116.27999877929688,
#     'volume': 43341200,
#     'adjclose': 108.52214813232422,
#     'formatted_date': '2015-09-15'},
#    {'date': 1442410200,
#     'high': 116.54000091552734,
#     'low': 115.44000244140625,
#     'open': 116.25,
#     'close': 116.41000366210938,
#     'volume': 37173500,
#     'adjclose': 108.64347839355469,
#     'formatted_date': '2015-09-16'},
#    {'date': 1442496600,
#     'high': 116.48999786376953,
#     'low': 113.72000122070312,
#     'open': 115.66000366210938,
#     'close': 113.91999816894531,
#     'volume': 64112600,
#     'adjclose': 106.31961059570312,
#     'formatted_date': '2015-09-17'},
#    {'date': 1442583000,
#     'high': 114.30000305175781,
#     'low': 111.87000274658203,
#     'open': 112.20999908447266,
#     'close': 113.44999694824219,
#     'volume': 74285300,
#     'adjclose': 105.8809585571289,
#     'formatted_date': '2015-09-18'},
#    {'date': 1442842200,
#     'high': 115.37000274658203,
#     'low': 113.66000366210938,
#     'open': 113.66999816894531,
#     'close': 115.20999908447266,
#     'volume': 50222000,
#     'adjclose': 107.52354431152344,
#     'formatted_date': '2015-09-21'},
#    {'date': 1442928600,
#     'high': 114.18000030517578,
#     'low': 112.5199966430664,
#     'open': 113.37999725341797,
#     'close': 113.4000015258789,
#     'volume': 50346200,
#     'adjclose': 105.83430480957031,
#     'formatted_date': '2015-09-22'},
#    {'date': 1443015000,
#     'high': 114.72000122070312,
#     'low': 113.30000305175781,
#     'open': 113.62999725341797,
#     'close': 114.31999969482422,
#     'volume': 35756700,
#     'adjclose': 106.69291687011719,
#     'formatted_date': '2015-09-23'},
#    {'date': 1443101400,
#     'high': 115.5,
#     'low': 112.37000274658203,
#     'open': 113.25,
#     'close': 115.0,
#     'volume': 50219500,
#     'adjclose': 107.32756805419922,
#     'formatted_date': '2015-09-24'},
#    {'date': 1443187800,
#     'high': 116.69000244140625,
#     'low': 114.0199966430664,
#     'open': 116.44000244140625,
#     'close': 114.70999908447266,
#     'volume': 56151900,
#     'adjclose': 107.05689239501953,
#     'formatted_date': '2015-09-25'},
#    {'date': 1443447000,
#     'high': 114.56999969482422,
#     'low': 112.44000244140625,
#     'open': 113.8499984741211,
#     'close': 112.44000244140625,
#     'volume': 52109000,
#     'adjclose': 104.93833923339844,
#     'formatted_date': '2015-09-28'},
#    {'date': 1443533400,
#     'high': 113.51000213623047,
#     'low': 107.86000061035156,
#     'open': 112.83000183105469,
#     'close': 109.05999755859375,
#     'volume': 73365400,
#     'adjclose': 101.78384399414062,
#     'formatted_date': '2015-09-29'},
#    {'date': 1443619800,
#     'high': 111.54000091552734,
#     'low': 108.7300033569336,
#     'open': 110.16999816894531,
#     'close': 110.30000305175781,
#     'volume': 66473000,
#     'adjclose': 102.94112396240234,
#     'formatted_date': '2015-09-30'},
#    {'date': 1443706200,
#     'high': 109.62000274658203,
#     'low': 107.30999755859375,
#     'open': 109.06999969482422,
#     'close': 109.58000183105469,
#     'volume': 63929100,
#     'adjclose': 102.26915740966797,
#     'formatted_date': '2015-10-01'},
#    {'date': 1443792600,
#     'high': 111.01000213623047,
#     'low': 107.55000305175781,
#     'open': 108.01000213623047,
#     'close': 110.37999725341797,
#     'volume': 58019800,
#     'adjclose': 103.01578521728516,
#     'formatted_date': '2015-10-02'},
#    {'date': 1444051800,
#     'high': 111.37000274658203,
#     'low': 109.06999969482422,
#     'open': 109.87999725341797,
#     'close': 110.77999877929688,
#     'volume': 52064700,
#     'adjclose': 103.38910675048828,
#     'formatted_date': '2015-10-05'},
#    {'date': 1444138200,
#     'high': 111.73999786376953,
#     'low': 109.7699966430664,
#     'open': 110.62999725341797,
#     'close': 111.30999755859375,
#     'volume': 48196800,
#     'adjclose': 103.88373565673828,
#     'formatted_date': '2015-10-06'},
#    {'date': 1444224600,
#     'high': 111.7699966430664,
#     'low': 109.41000366210938,
#     'open': 111.73999786376953,
#     'close': 110.77999877929688,
#     'volume': 46765600,
#     'adjclose': 103.38910675048828,
#     'formatted_date': '2015-10-07'},
#    {'date': 1444311000,
#     'high': 110.19000244140625,
#     'low': 108.20999908447266,
#     'open': 110.19000244140625,
#     'close': 109.5,
#     'volume': 61979600,
#     'adjclose': 102.1944808959961,
#     'formatted_date': '2015-10-08'},
#    {'date': 1444397400,
#     'high': 112.27999877929688,
#     'low': 109.48999786376953,
#     'open': 110.0,
#     'close': 112.12000274658203,
#     'volume': 52766100,
#     'adjclose': 104.63971710205078,
#     'formatted_date': '2015-10-09'},
#    {'date': 1444656600,
#     'high': 112.75,
#     'low': 111.44000244140625,
#     'open': 112.7300033569336,
#     'close': 111.5999984741211,
#     'volume': 30467200,
#     'adjclose': 104.15436553955078,
#     'formatted_date': '2015-10-12'},
#    {'date': 1444743000,
#     'high': 112.44999694824219,
#     'low': 110.68000030517578,
#     'open': 110.81999969482422,
#     'close': 111.79000091552734,
#     'volume': 33049300,
#     'adjclose': 104.33171081542969,
#     'formatted_date': '2015-10-13'},
#    {'date': 1444829400,
#     'high': 111.5199966430664,
#     'low': 109.55999755859375,
#     'open': 111.29000091552734,
#     'close': 110.20999908447266,
#     'volume': 44462400,
#     'adjclose': 102.85713195800781,
#     'formatted_date': '2015-10-14'},
#    {'date': 1444915800,
#     'high': 112.0999984741211,
#     'low': 110.48999786376953,
#     'open': 110.93000030517578,
#     'close': 111.86000061035156,
#     'volume': 37673500,
#     'adjclose': 104.39704895019531,
#     'formatted_date': '2015-10-15'},
#    {'date': 1445002200,
#     'high': 112.0,
#     'low': 110.52999877929688,
#     'open': 111.77999877929688,
#     'close': 111.04000091552734,
#     'volume': 39232600,
#     'adjclose': 103.63176727294922,
#     'formatted_date': '2015-10-16'},
#    {'date': 1445261400,
#     'high': 111.75,
#     'low': 110.11000061035156,
#     'open': 110.80000305175781,
#     'close': 111.7300033569336,
#     'volume': 29759200,
#     'adjclose': 104.27571105957031,
#     'formatted_date': '2015-10-19'},
#    {'date': 1445347800,
#     'high': 114.16999816894531,
#     'low': 110.81999969482422,
#     'open': 111.33999633789062,
#     'close': 113.7699966430664,
#     'volume': 48967800,
#     'adjclose': 106.17964172363281,
#     'formatted_date': '2015-10-20'},
#    {'date': 1445434200,
#     'high': 115.58000183105469,
#     'low': 113.69999694824219,
#     'open': 114.0,
#     'close': 113.76000213623047,
#     'volume': 41795200,
#     'adjclose': 106.17029571533203,
#     'formatted_date': '2015-10-21'},
#    {'date': 1445520600,
#     'high': 115.5,
#     'low': 114.0999984741211,
#     'open': 114.33000183105469,
#     'close': 115.5,
#     'volume': 41654100,
#     'adjclose': 107.794189453125,
#     'formatted_date': '2015-10-22'},
#    {'date': 1445607000,
#     'high': 119.2300033569336,
#     'low': 116.33000183105469,
#     'open': 116.69999694824219,
#     'close': 119.08000183105469,
#     'volume': 59366900,
#     'adjclose': 111.1353530883789,
#     'formatted_date': '2015-10-23'},
#    {'date': 1445866200,
#     'high': 118.12999725341797,
#     'low': 114.91999816894531,
#     'open': 118.08000183105469,
#     'close': 115.27999877929688,
#     'volume': 66333800,
#     'adjclose': 107.5888671875,
#     'formatted_date': '2015-10-26'},
#    {'date': 1445952600,
#     'high': 116.54000091552734,
#     'low': 113.98999786376953,
#     'open': 115.4000015258789,
#     'close': 114.55000305175781,
#     'volume': 69884400,
#     'adjclose': 106.9075698852539,
#     'formatted_date': '2015-10-27'},
#    {'date': 1446039000,
#     'high': 119.30000305175781,
#     'low': 116.05999755859375,
#     'open': 116.93000030517578,
#     'close': 119.2699966430664,
#     'volume': 85551400,
#     'adjclose': 111.31266784667969,
#     'formatted_date': '2015-10-28'},
#    {'date': 1446125400,
#     'high': 120.69000244140625,
#     'low': 118.2699966430664,
#     'open': 118.69999694824219,
#     'close': 120.52999877929688,
#     'volume': 51227300,
#     'adjclose': 112.48859405517578,
#     'formatted_date': '2015-10-29'},
#    {'date': 1446211800,
#     'high': 121.22000122070312,
#     'low': 119.44999694824219,
#     'open': 120.98999786376953,
#     'close': 119.5,
#     'volume': 49365300,
#     'adjclose': 111.52732849121094,
#     'formatted_date': '2015-10-30'},
#    {'date': 1446474600,
#     'high': 121.36000061035156,
#     'low': 119.61000061035156,
#     'open': 120.80000305175781,
#     'close': 121.18000030517578,
#     'volume': 32203300,
#     'adjclose': 113.09524536132812,
#     'formatted_date': '2015-11-02'},
#    {'date': 1446561000,
#     'high': 123.48999786376953,
#     'low': 120.69999694824219,
#     'open': 120.79000091552734,
#     'close': 122.56999969482422,
#     'volume': 45519000,
#     'adjclose': 114.39250183105469,
#     'formatted_date': '2015-11-03'},
#    {'date': 1446647400,
#     'high': 123.81999969482422,
#     'low': 121.62000274658203,
#     'open': 123.12999725341797,
#     'close': 122.0,
#     'volume': 44886100,
#     'adjclose': 113.86053466796875,
#     'formatted_date': '2015-11-04'},
#    {'date': 1446733800,
#     'high': 122.69000244140625,
#     'low': 120.18000030517578,
#     'open': 121.8499984741211,
#     'close': 120.91999816894531,
#     'volume': 39552700,
#     'adjclose': 113.33565521240234,
#     'formatted_date': '2015-11-05'},
#    {'date': 1446820200,
#     'high': 121.80999755859375,
#     'low': 120.62000274658203,
#     'open': 121.11000061035156,
#     'close': 121.05999755859375,
#     'volume': 33042300,
#     'adjclose': 113.46687316894531,
#     'formatted_date': '2015-11-06'},
#    {'date': 1447079400,
#     'high': 121.80999755859375,
#     'low': 120.05000305175781,
#     'open': 120.95999908447266,
#     'close': 120.56999969482422,
#     'volume': 33871400,
#     'adjclose': 113.00760650634766,
#     'formatted_date': '2015-11-09'},
#    {'date': 1447165800,
#     'high': 118.06999969482422,
#     'low': 116.05999755859375,
#     'open': 116.9000015258789,
#     'close': 116.7699966430664,
#     'volume': 59127900,
#     'adjclose': 109.44595336914062,
#     'formatted_date': '2015-11-10'},
#    {'date': 1447252200,
#     'high': 117.41999816894531,
#     'low': 115.20999908447266,
#     'open': 116.37000274658203,
#     'close': 116.11000061035156,
#     'volume': 45218000,
#     'adjclose': 108.82733917236328,
#     'formatted_date': '2015-11-11'},
#    {'date': 1447338600,
#     'high': 116.81999969482422,
#     'low': 115.6500015258789,
#     'open': 116.26000213623047,
#     'close': 115.72000122070312,
#     'volume': 32525600,
#     'adjclose': 108.46180725097656,
#     'formatted_date': '2015-11-12'},
#    {'date': 1447425000,
#     'high': 115.56999969482422,
#     'low': 112.2699966430664,
#     'open': 115.19999694824219,
#     'close': 112.33999633789062,
#     'volume': 45812400,
#     'adjclose': 105.29380798339844,
#     'formatted_date': '2015-11-13'},
#    {'date': 1447684200,
#     'high': 114.23999786376953,
#     'low': 111.0,
#     'open': 111.37999725341797,
#     'close': 114.18000030517578,
#     'volume': 38106700,
#     'adjclose': 107.01840209960938,
#     'formatted_date': '2015-11-16'},
#    {'date': 1447770600,
#     'high': 115.05000305175781,
#     'low': 113.31999969482422,
#     'open': 114.91999816894531,
#     'close': 113.69000244140625,
#     'volume': 27616900,
#     'adjclose': 106.55913543701172,
#     'formatted_date': '2015-11-17'},
#    {'date': 1447857000,
#     'high': 117.48999786376953,
#     'low': 115.5,
#     'open': 115.76000213623047,
#     'close': 117.29000091552734,
#     'volume': 46674700,
#     'adjclose': 109.93334197998047,
#     'formatted_date': '2015-11-18'},
#    {'date': 1447943400,
#     'high': 119.75,
#     'low': 116.76000213623047,
#     'open': 117.63999938964844,
#     'close': 118.77999877929688,
#     'volume': 43295800,
#     'adjclose': 111.32989501953125,
#     'formatted_date': '2015-11-19'},
#    {'date': 1448029800,
#     'high': 119.91999816894531,
#     'low': 118.8499984741211,
#     'open': 119.19999694824219,
#     'close': 119.30000305175781,
#     'volume': 34287100,
#     'adjclose': 111.8172607421875,
#     'formatted_date': '2015-11-20'},
#    {'date': 1448289000,
#     'high': 119.7300033569336,
#     'low': 117.33999633789062,
#     'open': 119.2699966430664,
#     'close': 117.75,
#     'volume': 32482500,
#     'adjclose': 110.36449432373047,
#     'formatted_date': '2015-11-23'},
#    {'date': 1448375400,
#     'high': 119.3499984741211,
#     'low': 117.12000274658203,
#     'open': 117.33000183105469,
#     'close': 118.87999725341797,
#     'volume': 42803200,
#     'adjclose': 111.42359924316406,
#     'formatted_date': '2015-11-24'},
#    {'date': 1448461800,
#     'high': 119.2300033569336,
#     'low': 117.91999816894531,
#     'open': 119.20999908447266,
#     'close': 118.02999877929688,
#     'volume': 21388300,
#     'adjclose': 110.62692260742188,
#     'formatted_date': '2015-11-25'},
#    {'date': 1448634600,
#     'high': 118.41000366210938,
#     'low': 117.5999984741211,
#     'open': 118.29000091552734,
#     'close': 117.80999755859375,
#     'volume': 13046400,
#     'adjclose': 110.42073059082031,
#     'formatted_date': '2015-11-27'},
#    {'date': 1448893800,
#     'high': 119.41000366210938,
#     'low': 117.75,
#     'open': 117.98999786376953,
#     'close': 118.30000305175781,
#     'volume': 39180300,
#     'adjclose': 110.87999725341797,
#     'formatted_date': '2015-11-30'},
#    {'date': 1448980200,
#     'high': 118.80999755859375,
#     'low': 116.86000061035156,
#     'open': 118.75,
#     'close': 117.33999633789062,
#     'volume': 34852400,
#     'adjclose': 109.98018646240234,
#     'formatted_date': '2015-12-01'},
#    {'date': 1449066600,
#     'high': 118.11000061035156,
#     'low': 116.08000183105469,
#     'open': 117.33999633789062,
#     'close': 116.27999877929688,
#     'volume': 33386600,
#     'adjclose': 108.98667907714844,
#     'formatted_date': '2015-12-02'},
#    {'date': 1449153000,
#     'high': 116.79000091552734,
#     'low': 114.22000122070312,
#     'open': 116.55000305175781,
#     'close': 115.19999694824219,
#     'volume': 41569500,
#     'adjclose': 107.97441864013672,
#     'formatted_date': '2015-12-03'},
#    {'date': 1449239400,
#     'high': 119.25,
#     'low': 115.11000061035156,
#     'open': 115.29000091552734,
#     'close': 119.02999877929688,
#     'volume': 57777000,
#     'adjclose': 111.56419372558594,
#     'formatted_date': '2015-12-04'},
#    {'date': 1449498600,
#     'high': 119.86000061035156,
#     'low': 117.80999755859375,
#     'open': 118.9800033569336,
#     'close': 118.27999877929688,
#     'volume': 32084200,
#     'adjclose': 110.86124420166016,
#     'formatted_date': '2015-12-07'},
#    {'date': 1449585000,
#     'high': 118.5999984741211,
#     'low': 116.86000061035156,
#     'open': 117.5199966430664,
#     'close': 118.2300033569336,
#     'volume': 34309500,
#     'adjclose': 110.81437683105469,
#     'formatted_date': '2015-12-08'},
#    {'date': 1449671400,
#     'high': 117.69000244140625,
#     'low': 115.08000183105469,
#     'open': 117.63999938964844,
#     'close': 115.62000274658203,
#     'volume': 46361400,
#     'adjclose': 108.36808013916016,
#     'formatted_date': '2015-12-09'},
#    {'date': 1449757800,
#     'high': 116.94000244140625,
#     'low': 115.51000213623047,
#     'open': 116.04000091552734,
#     'close': 116.16999816894531,
#     'volume': 29212700,
#     'adjclose': 108.88358306884766,
#     'formatted_date': '2015-12-10'},
#    {'date': 1449844200,
#     'high': 115.38999938964844,
#     'low': 112.8499984741211,
#     'open': 115.19000244140625,
#     'close': 113.18000030517578,
#     'volume': 46886200,
#     'adjclose': 106.08112335205078,
#     'formatted_date': '2015-12-11'},
#    {'date': 1450103400,
#     'high': 112.68000030517578,
#     'low': 109.79000091552734,
#     'open': 112.18000030517578,
#     'close': 112.4800033569336,
#     'volume': 64318700,
#     'adjclose': 105.4250259399414,
#     'formatted_date': '2015-12-14'},
#    {'date': 1450189800,
#     'high': 112.80000305175781,
#     'low': 110.3499984741211,
#     'open': 111.94000244140625,
#     'close': 110.48999786376953,
#     'volume': 53323100,
#     'adjclose': 103.55984497070312,
#     'formatted_date': '2015-12-15'},
#    {'date': 1450276200,
#     'high': 111.98999786376953,
#     'low': 108.80000305175781,
#     'open': 111.06999969482422,
#     'close': 111.33999633789062,
#     'volume': 56238500,
#     'adjclose': 104.35651397705078,
#     'formatted_date': '2015-12-16'},
#    {'date': 1450362600,
#     'high': 112.25,
#     'low': 108.9800033569336,
#     'open': 112.0199966430664,
#     'close': 108.9800033569336,
#     'volume': 44772800,
#     'adjclose': 102.1445541381836,
#     'formatted_date': '2015-12-17'},
#    {'date': 1450449000,
#     'high': 109.5199966430664,
#     'low': 105.80999755859375,
#     'open': 108.91000366210938,
#     'close': 106.02999877929688,
#     'volume': 96453300,
#     'adjclose': 99.37958526611328,
#     'formatted_date': '2015-12-18'},
#    {'date': 1450708200,
#     'high': 107.37000274658203,
#     'low': 105.56999969482422,
#     'open': 107.27999877929688,
#     'close': 107.33000183105469,
#     'volume': 47590600,
#     'adjclose': 100.5980453491211,
#     'formatted_date': '2015-12-21'},
#    {'date': 1450794600,
#     'high': 107.72000122070312,
#     'low': 106.44999694824219,
#     'open': 107.4000015258789,
#     'close': 107.2300033569336,
#     'volume': 32789400,
#     'adjclose': 100.50433349609375,
#     'formatted_date': '2015-12-22'},
#    {'date': 1450881000,
#     'high': 108.8499984741211,
#     'low': 107.19999694824219,
#     'open': 107.2699966430664,
#     'close': 108.61000061035156,
#     'volume': 32657400,
#     'adjclose': 101.79776000976562,
#     'formatted_date': '2015-12-23'},
#    {'date': 1450967400,
#     'high': 109.0,
#     'low': 107.94999694824219,
#     'open': 109.0,
#     'close': 108.02999877929688,
#     'volume': 13570400,
#     'adjclose': 101.25414276123047,
#     'formatted_date': '2015-12-24'},
#    {'date': 1451313000,
#     'high': 107.69000244140625,
#     'low': 106.18000030517578,
#     'open': 107.58999633789062,
#     'close': 106.81999969482422,
#     'volume': 26704200,
#     'adjclose': 100.12003326416016,
#     'formatted_date': '2015-12-28'},
#    {'date': 1451399400,
#     'high': 109.43000030517578,
#     'low': 106.86000061035156,
#     'open': 106.95999908447266,
#     'close': 108.73999786376953,
#     'volume': 30931200,
#     'adjclose': 101.91960906982422,
#     'formatted_date': '2015-12-29'},
#    {'date': 1451485800,
#     'high': 108.69999694824219,
#     'low': 107.18000030517578,
#     'open': 108.58000183105469,
#     'close': 107.31999969482422,
#     'volume': 25213800,
#     'adjclose': 100.58867645263672,
#     'formatted_date': '2015-12-30'},
#    {'date': 1451572200,
#     'high': 107.02999877929688,
#     'low': 104.81999969482422,
#     'open': 107.01000213623047,
#     'close': 105.26000213623047,
#     'volume': 40912300,
#     'adjclose': 98.65788269042969,
#     'formatted_date': '2015-12-31'},
#    {'date': 1451917800,
#     'high': 105.37000274658203,
#     'low': 102.0,
#     'open': 102.61000061035156,
#     'close': 105.3499984741211,
#     'volume': 67649400,
#     'adjclose': 98.74224853515625,
#     'formatted_date': '2016-01-04'},
#    {'date': 1452004200,
#     'high': 105.8499984741211,
#     'low': 102.41000366210938,
#     'open': 105.75,
#     'close': 102.70999908447266,
#     'volume': 55791000,
#     'adjclose': 96.26781463623047,
#     'formatted_date': '2016-01-05'},
#    {'date': 1452090600,
#     'high': 102.37000274658203,
#     'low': 99.87000274658203,
#     'open': 100.55999755859375,
#     'close': 100.69999694824219,
#     'volume': 68457400,
#     'adjclose': 94.3838882446289,
#     'formatted_date': '2016-01-06'},
#    {'date': 1452177000,
#     'high': 100.12999725341797,
#     'low': 96.43000030517578,
#     'open': 98.68000030517578,
#     'close': 96.44999694824219,
#     'volume': 81094400,
#     'adjclose': 90.40046691894531,
#     'formatted_date': '2016-01-07'},
#    {'date': 1452263400,
#     'high': 99.11000061035156,
#     'low': 96.76000213623047,
#     'open': 98.55000305175781,
#     'close': 96.95999908447266,
#     'volume': 70798000,
#     'adjclose': 90.87847900390625,
#     'formatted_date': '2016-01-08'},
#    {'date': 1452522600,
#     'high': 99.05999755859375,
#     'low': 97.33999633789062,
#     'open': 98.97000122070312,
#     'close': 98.52999877929688,
#     'volume': 49739400,
#     'adjclose': 92.35000610351562,
#     'formatted_date': '2016-01-11'},
#    {'date': 1452609000,
#     'high': 100.69000244140625,
#     'low': 98.83999633789062,
#     'open': 100.55000305175781,
#     'close': 99.95999908447266,
#     'volume': 49154200,
#     'adjclose': 93.69029998779297,
#     'formatted_date': '2016-01-12'},
#    {'date': 1452695400,
#     'high': 101.19000244140625,
#     'low': 97.30000305175781,
#     'open': 100.31999969482422,
#     'close': 97.38999938964844,
#     'volume': 62439600,
#     'adjclose': 91.281494140625,
#     'formatted_date': '2016-01-13'},
#    {'date': 1452781800,
#     'high': 100.4800033569336,
#     'low': 95.73999786376953,
#     'open': 97.95999908447266,
#     'close': 99.5199966430664,
#     'volume': 63170100,
#     'adjclose': 93.27791595458984,
#     'formatted_date': '2016-01-14'},
#    {'date': 1452868200,
#     'high': 97.70999908447266,
#     'low': 95.36000061035156,
#     'open': 96.19999694824219,
#     'close': 97.12999725341797,
#     'volume': 79833900,
#     'adjclose': 91.03781127929688,
#     'formatted_date': '2016-01-15'},
#    {'date': 1453213800,
#     'high': 98.6500015258789,
#     'low': 95.5,
#     'open': 98.41000366210938,
#     'close': 96.66000366210938,
#     'volume': 53087700,
#     'adjclose': 90.5972900390625,
#     'formatted_date': '2016-01-19'},
#    {'date': 1453300200,
#     'high': 98.19000244140625,
#     'low': 93.41999816894531,
#     'open': 95.0999984741211,
#     'close': 96.79000091552734,
#     'volume': 72334400,
#     'adjclose': 90.71913146972656,
#     'formatted_date': '2016-01-20'},
#    {'date': 1453386600,
#     'high': 97.87999725341797,
#     'low': 94.94000244140625,
#     'open': 97.05999755859375,
#     'close': 96.30000305175781,
#     'volume': 52161500,
#     'adjclose': 90.25987243652344,
#     'formatted_date': '2016-01-21'},
#    {'date': 1453473000,
#     'high': 101.45999908447266,
#     'low': 98.37000274658203,
#     'open': 98.62999725341797,
#     'close': 101.41999816894531,
#     'volume': 65800500,
#     'adjclose': 95.0587387084961,
#     'formatted_date': '2016-01-22'},
#    {'date': 1453732200,
#     'high': 101.52999877929688,
#     'low': 99.20999908447266,
#     'open': 101.5199966430664,
#     'close': 99.44000244140625,
#     'volume': 51794500,
#     'adjclose': 93.20293426513672,
#     'formatted_date': '2016-01-25'},
#    {'date': 1453818600,
#     'high': 100.87999725341797,
#     'low': 98.06999969482422,
#     'open': 99.93000030517578,
#     'close': 99.98999786376953,
#     'volume': 75077000,
#     'adjclose': 93.71843719482422,
#     'formatted_date': '2016-01-26'},
#    {'date': 1453905000,
#     'high': 96.62999725341797,
#     'low': 93.33999633789062,
#     'open': 96.04000091552734,
#     'close': 93.41999816894531,
#     'volume': 133369700,
#     'adjclose': 87.56050872802734,
#     'formatted_date': '2016-01-27'},
#    {'date': 1453991400,
#     'high': 94.5199966430664,
#     'low': 92.38999938964844,
#     'open': 93.79000091552734,
#     'close': 94.08999633789062,
#     'volume': 55678800,
#     'adjclose': 88.18848419189453,
#     'formatted_date': '2016-01-28'},
#    {'date': 1454077800,
#     'high': 97.33999633789062,
#     'low': 94.3499984741211,
#     'open': 94.79000091552734,
#     'close': 97.33999633789062,
#     'volume': 64416500,
#     'adjclose': 91.23464965820312,
#     'formatted_date': '2016-01-29'},
#    {'date': 1454337000,
#     'high': 96.70999908447266,
#     'low': 95.4000015258789,
#     'open': 96.47000122070312,
#     'close': 96.43000030517578,
#     'volume': 40943500,
#     'adjclose': 90.38172149658203,
#     'formatted_date': '2016-02-01'},
#    {'date': 1454423400,
#     'high': 96.04000091552734,
#     'low': 94.27999877929688,
#     'open': 95.41999816894531,
#     'close': 94.4800033569336,
#     'volume': 37357200,
#     'adjclose': 88.55402374267578,
#     'formatted_date': '2016-02-02'},
#    {'date': 1454509800,
#     'high': 96.83999633789062,
#     'low': 94.08000183105469,
#     'open': 95.0,
#     'close': 96.3499984741211,
#     'volume': 45964300,
#     'adjclose': 90.30672454833984,
#     'formatted_date': '2016-02-03'},
#    {'date': 1454596200,
#     'high': 97.33000183105469,
#     'low': 95.19000244140625,
#     'open': 95.86000061035156,
#     'close': 96.5999984741211,
#     'volume': 46471700,
#     'adjclose': 91.03235626220703,
#     'formatted_date': '2016-02-04'},
#    {'date': 1454682600,
#     'high': 96.91999816894531,
#     'low': 93.69000244140625,
#     'open': 96.5199966430664,
#     'close': 94.0199966430664,
#     'volume': 46418100,
#     'adjclose': 88.60105895996094,
#     'formatted_date': '2016-02-05'},
#    {'date': 1454941800,
#     'high': 95.69999694824219,
#     'low': 93.04000091552734,
#     'open': 93.12999725341797,
#     'close': 95.01000213623047,
#     'volume': 54021400,
#     'adjclose': 89.53398895263672,
#     'formatted_date': '2016-02-08'},
#    {'date': 1455028200,
#     'high': 95.94000244140625,
#     'low': 93.93000030517578,
#     'open': 94.29000091552734,
#     'close': 94.98999786376953,
#     'volume': 44331200,
#     'adjclose': 89.51514434814453,
#     'formatted_date': '2016-02-09'},
#    {'date': 1455114600,
#     'high': 96.3499984741211,
#     'low': 94.0999984741211,
#     'open': 95.91999816894531,
#     'close': 94.2699966430664,
#     'volume': 42343600,
#     'adjclose': 88.83665466308594,
#     'formatted_date': '2016-02-10'},
#    {'date': 1455201000,
#     'high': 94.72000122070312,
#     'low': 92.58999633789062,
#     'open': 93.79000091552734,
#     'close': 93.69999694824219,
#     'volume': 50074700,
#     'adjclose': 88.29949188232422,
#     'formatted_date': '2016-02-11'},
#    {'date': 1455287400,
#     'high': 94.5,
#     'low': 93.01000213623047,
#     'open': 94.19000244140625,
#     'close': 93.98999786376953,
#     'volume': 40351400,
#     'adjclose': 88.57278442382812,
#     'formatted_date': '2016-02-12'},
#    {'date': 1455633000,
#     'high': 96.8499984741211,
#     'low': 94.61000061035156,
#     'open': 95.0199966430664,
#     'close': 96.63999938964844,
#     'volume': 49057900,
#     'adjclose': 91.0700454711914,
#     'formatted_date': '2016-02-16'},
#    {'date': 1455719400,
#     'high': 98.20999908447266,
#     'low': 96.1500015258789,
#     'open': 96.66999816894531,
#     'close': 98.12000274658203,
#     'volume': 44863200,
#     'adjclose': 92.46475219726562,
#     'formatted_date': '2016-02-17'},
#    {'date': 1455805800,
#     'high': 98.88999938964844,
#     'low': 96.08999633789062,
#     'open': 98.83999633789062,
#     'close': 96.26000213623047,
#     'volume': 39021000,
#     'adjclose': 90.71195983886719,
#     'formatted_date': '2016-02-18'},
#    {'date': 1455892200,
#     'high': 96.76000213623047,
#     'low': 95.80000305175781,
#     'open': 96.0,
#     'close': 96.04000091552734,
#     'volume': 35374200,
#     'adjclose': 90.504638671875,
#     'formatted_date': '2016-02-19'},
#    {'date': 1456151400,
#     'high': 96.9000015258789,
#     'low': 95.91999816894531,
#     'open': 96.30999755859375,
#     'close': 96.87999725341797,
#     'volume': 34280800,
#     'adjclose': 91.29621887207031,
#     'formatted_date': '2016-02-22'},
#    {'date': 1456237800,
#     'high': 96.5,
#     'low': 94.55000305175781,
#     'open': 96.4000015258789,
#     'close': 94.69000244140625,
#     'volume': 31942600,
#     'adjclose': 89.23242950439453,
#     'formatted_date': '2016-02-23'},
#    {'date': 1456324200,
#     'high': 96.37999725341797,
#     'low': 93.31999969482422,
#     'open': 93.9800033569336,
#     'close': 96.0999984741211,
#     'volume': 36255700,
#     'adjclose': 90.56116485595703,
#     'formatted_date': '2016-02-24'},
#    {'date': 1456410600,
#     'high': 96.76000213623047,
#     'low': 95.25,
#     'open': 96.05000305175781,
#     'close': 96.76000213623047,
#     'volume': 27582700,
#     'adjclose': 91.18312072753906,
#     'formatted_date': '2016-02-25'},
#    {'date': 1456497000,
#     'high': 98.0199966430664,
#     'low': 96.58000183105469,
#     'open': 97.19999694824219,
#     'close': 96.91000366210938,
#     'volume': 28991100,
#     'adjclose': 91.32449340820312,
#     'formatted_date': '2016-02-26'},
#    {'date': 1456756200,
#     'high': 98.2300033569336,
#     'low': 96.6500015258789,
#     'open': 96.86000061035156,
#     'close': 96.69000244140625,
#     'volume': 35216300,
#     'adjclose': 91.11715698242188,
#     'formatted_date': '2016-02-29'},
#    {'date': 1456842600,
#     'high': 100.7699966430664,
#     'low': 97.41999816894531,
#     'open': 97.6500015258789,
#     'close': 100.52999877929688,
#     'volume': 50407100,
#     'adjclose': 94.73583984375,
#     'formatted_date': '2016-03-01'},
#    {'date': 1456929000,
#     'high': 100.88999938964844,
#     'low': 99.63999938964844,
#     'open': 100.51000213623047,
#     'close': 100.75,
#     'volume': 33169600,
#     'adjclose': 94.94316101074219,
#     'formatted_date': '2016-03-02'},
#    {'date': 1457015400,
#     'high': 101.70999908447266,
#     'low': 100.44999694824219,
#     'open': 100.58000183105469,
#     'close': 101.5,
#     'volume': 36955700,
#     'adjclose': 95.64993286132812,
#     'formatted_date': '2016-03-03'},
#    {'date': 1457101800,
#     'high': 103.75,
#     'low': 101.37000274658203,
#     'open': 102.37000274658203,
#     'close': 103.01000213623047,
#     'volume': 46055100,
#     'adjclose': 97.07290649414062,
#     'formatted_date': '2016-03-04'},
#    {'date': 1457361000,
#     'high': 102.83000183105469,
#     'low': 100.95999908447266,
#     'open': 102.38999938964844,
#     'close': 101.87000274658203,
#     'volume': 35828900,
#     'adjclose': 95.99861907958984,
#     'formatted_date': '2016-03-07'},
#    {'date': 1457447400,
#     'high': 101.76000213623047,
#     'low': 100.4000015258789,
#     'open': 100.77999877929688,
#     'close': 101.02999877929688,
#     'volume': 31561900,
#     'adjclose': 95.20703125,
#     'formatted_date': '2016-03-08'},
#    {'date': 1457533800,
#     'high': 101.58000183105469,
#     'low': 100.2699966430664,
#     'open': 101.30999755859375,
#     'close': 101.12000274658203,
#     'volume': 27201700,
#     'adjclose': 95.29185485839844,
#     'formatted_date': '2016-03-09'},
#    {'date': 1457620200,
#     'high': 102.23999786376953,
#     'low': 100.1500015258789,
#     'open': 101.41000366210938,
#     'close': 101.16999816894531,
#     'volume': 33513600,
#     'adjclose': 95.33894348144531,
#     'formatted_date': '2016-03-10'},
#    {'date': 1457706600,
#     'high': 102.27999877929688,
#     'low': 101.5,
#     'open': 102.23999786376953,
#     'close': 102.26000213623047,
#     'volume': 27408200,
#     'adjclose': 96.36614227294922,
#     'formatted_date': '2016-03-11'},
#    {'date': 1457962200,
#     'high': 102.91000366210938,
#     'low': 101.77999877929688,
#     'open': 101.91000366210938,
#     'close': 102.5199966430664,
#     'volume': 25076100,
#     'adjclose': 96.61114501953125,
#     'formatted_date': '2016-03-14'},
#    {'date': 1458048600,
#     'high': 105.18000030517578,
#     'low': 103.8499984741211,
#     'open': 103.95999908447266,
#     'close': 104.58000183105469,
#     'volume': 40067700,
#     'adjclose': 98.55241394042969,
#     'formatted_date': '2016-03-15'},
#    {'date': 1458135000,
#     'high': 106.30999755859375,
#     'low': 104.58999633789062,
#     'open': 104.61000061035156,
#     'close': 105.97000122070312,
#     'volume': 38303500,
#     'adjclose': 99.8623046875,
#     'formatted_date': '2016-03-16'},
#    {'date': 1458221400,
#     'high': 106.47000122070312,
#     'low': 104.95999908447266,
#     'open': 105.5199966430664,
#     'close': 105.80000305175781,
#     'volume': 34420700,
#     'adjclose': 99.70211029052734,
#     'formatted_date': '2016-03-17'},
#    {'date': 1458307800,
#     'high': 106.5,
#     'low': 105.19000244140625,
#     'open': 106.33999633789062,
#     'close': 105.91999816894531,
#     'volume': 44205200,
#     'adjclose': 99.81517791748047,
#     'formatted_date': '2016-03-18'},
#    {'date': 1458567000,
#     'high': 107.6500015258789,
#     'low': 105.13999938964844,
#     'open': 105.93000030517578,
#     'close': 105.91000366210938,
#     'volume': 35502700,
#     'adjclose': 99.8057632446289,
#     'formatted_date': '2016-03-21'},
#    {'date': 1458653400,
#     'high': 107.29000091552734,
#     'low': 105.20999908447266,
#     'open': 105.25,
#     'close': 106.72000122070312,
#     'volume': 32444400,
#     'adjclose': 100.56906127929688,
#     'formatted_date': '2016-03-22'},
#    {'date': 1458739800,
#     'high': 107.06999969482422,
#     'low': 105.9000015258789,
#     'open': 106.4800033569336,
#     'close': 106.12999725341797,
#     'volume': 25703500,
#     'adjclose': 100.01307678222656,
#     'formatted_date': '2016-03-23'},
#    {'date': 1458826200,
#     'high': 106.25,
#     'low': 104.88999938964844,
#     'open': 105.47000122070312,
#     'close': 105.66999816894531,
#     'volume': 26133000,
#     'adjclose': 99.57960510253906,
#     'formatted_date': '2016-03-24'},
#    {'date': 1459171800,
#     'high': 106.19000244140625,
#     'low': 105.05999755859375,
#     'open': 106.0,
#     'close': 105.19000244140625,
#     'volume': 19411400,
#     'adjclose': 99.12726593017578,
#     'formatted_date': '2016-03-28'},
#    {'date': 1459258200,
#     'high': 107.79000091552734,
#     'low': 104.87999725341797,
#     'open': 104.88999938964844,
#     'close': 107.68000030517578,
#     'volume': 31190100,
#     'adjclose': 101.47373962402344,
#     'formatted_date': '2016-03-29'},
#    {'date': 1459344600,
#     'high': 110.41999816894531,
#     'low': 108.5999984741211,
#     'open': 108.6500015258789,
#     'close': 109.55999755859375,
#     'volume': 45601100,
#     'adjclose': 103.2453842163086,
#     'formatted_date': '2016-03-30'},
#    {'date': 1459431000,
#     'high': 109.9000015258789,
#     'low': 108.87999725341797,
#     'open': 109.72000122070312,
#     'close': 108.98999786376953,
#     'volume': 25888400,
#     'adjclose': 102.70824432373047,
#     'formatted_date': '2016-03-31'},
#    {'date': 1459517400,
#     'high': 110.0,
#     'low': 108.19999694824219,
#     'open': 108.77999877929688,
#     'close': 109.98999786376953,
#     'volume': 25874000,
#     'adjclose': 103.65060424804688,
#     'formatted_date': '2016-04-01'},
#    {'date': 1459776600,
#     'high': 112.19000244140625,
#     'low': 110.2699966430664,
#     'open': 110.41999816894531,
#     'close': 111.12000274658203,
#     'volume': 37356200,
#     'adjclose': 104.7154769897461,
#     'formatted_date': '2016-04-04'},
#    {'date': 1459863000,
#     'high': 110.7300033569336,
#     'low': 109.41999816894531,
#     'open': 109.51000213623047,
#     'close': 109.80999755859375,
#     'volume': 26578700,
#     'adjclose': 103.48098754882812,
#     'formatted_date': '2016-04-05'},
#    {'date': 1459949400,
#     'high': 110.9800033569336,
#     'low': 109.19999694824219,
#     'open': 110.2300033569336,
#     'close': 110.95999908447266,
#     'volume': 26404100,
#     'adjclose': 104.56468200683594,
#     'formatted_date': '2016-04-06'},
#    {'date': 1460035800,
#     'high': 110.41999816894531,
#     'low': 108.12000274658203,
#     'open': 109.94999694824219,
#     'close': 108.54000091552734,
#     'volume': 31801900,
#     'adjclose': 102.28417205810547,
#     'formatted_date': '2016-04-07'},
#    {'date': 1460122200,
#     'high': 109.7699966430664,
#     'low': 108.16999816894531,
#     'open': 108.91000366210938,
#     'close': 108.66000366210938,
#     'volume': 23581700,
#     'adjclose': 102.39727020263672,
#     'formatted_date': '2016-04-08'},
#    {'date': 1460381400,
#     'high': 110.61000061035156,
#     'low': 108.83000183105469,
#     'open': 108.97000122070312,
#     'close': 109.0199966430664,
#     'volume': 29407500,
#     'adjclose': 102.73651885986328,
#     'formatted_date': '2016-04-11'},
#    {'date': 1460467800,
#     'high': 110.5,
#     'low': 108.66000366210938,
#     'open': 109.33999633789062,
#     'close': 110.44000244140625,
#     'volume': 27232300,
#     'adjclose': 104.0746841430664,
#     'formatted_date': '2016-04-12'},
#    {'date': 1460554200,
#     'high': 112.33999633789062,
#     'low': 110.80000305175781,
#     'open': 110.80000305175781,
#     'close': 112.04000091552734,
#     'volume': 33257300,
#     'adjclose': 105.58246612548828,
#     'formatted_date': '2016-04-13'},
#    {'date': 1460640600,
#     'high': 112.38999938964844,
#     'low': 111.33000183105469,
#     'open': 111.62000274658203,
#     'close': 112.0999984741211,
#     'volume': 25473900,
#     'adjclose': 105.63898468017578,
#     'formatted_date': '2016-04-14'},
#    {'date': 1460727000,
#     'high': 112.30000305175781,
#     'low': 109.7300033569336,
#     'open': 112.11000061035156,
#     'close': 109.8499984741211,
#     'volume': 46939000,
#     'adjclose': 103.51866912841797,
#     'formatted_date': '2016-04-15'},
#    {'date': 1460986200,
#     'high': 108.94999694824219,
#     'low': 106.94000244140625,
#     'open': 108.88999938964844,
#     'close': 107.4800033569336,
#     'volume': 60821500,
#     'adjclose': 101.28527069091797,
#     'formatted_date': '2016-04-18'},
#    {'date': 1461072600,
#     'high': 108.0,
#     'low': 106.2300033569336,
#     'open': 107.87999725341797,
#     'close': 106.91000366210938,
#     'volume': 32384900,
#     'adjclose': 100.74813079833984,
#     'formatted_date': '2016-04-19'},
#    {'date': 1461159000,
#     'high': 108.08999633789062,
#     'low': 106.05999755859375,
#     'open': 106.63999938964844,
#     'close': 107.12999725341797,
#     'volume': 30611000,
#     'adjclose': 100.95545196533203,
#     'formatted_date': '2016-04-20'},
#    {'date': 1461245400,
#     'high': 106.93000030517578,
#     'low': 105.5199966430664,
#     'open': 106.93000030517578,
#     'close': 105.97000122070312,
#     'volume': 31552500,
#     'adjclose': 99.8623046875,
#     'formatted_date': '2016-04-21'},
#    {'date': 1461331800,
#     'high': 106.4800033569336,
#     'low': 104.62000274658203,
#     'open': 105.01000213623047,
#     'close': 105.68000030517578,
#     'volume': 33683100,
#     'adjclose': 99.58902740478516,
#     'formatted_date': '2016-04-22'},
#    {'date': 1461591000,
#     'high': 105.6500015258789,
#     'low': 104.51000213623047,
#     'open': 105.0,
#     'close': 105.08000183105469,
#     'volume': 28031600,
#     'adjclose': 99.02359771728516,
#     'formatted_date': '2016-04-25'},
#    {'date': 1461677400,
#     'high': 105.30000305175781,
#     'low': 103.91000366210938,
#     'open': 103.91000366210938,
#     'close': 104.3499984741211,
#     'volume': 56016200,
#     'adjclose': 98.33567810058594,
#     'formatted_date': '2016-04-26'},
#    {'date': 1461763800,
#     'high': 98.70999908447266,
#     'low': 95.68000030517578,
#     'open': 96.0,
#     'close': 97.81999969482422,
#     'volume': 114602100,
#     'adjclose': 92.18204498291016,
#     'formatted_date': '2016-04-27'},
#    {'date': 1461850200,
#     'high': 97.87999725341797,
#     'low': 94.25,
#     'open': 97.61000061035156,
#     'close': 94.83000183105469,
#     'volume': 82242700,
#     'adjclose': 89.36436462402344,
#     'formatted_date': '2016-04-28'},
#    {'date': 1461936600,
#     'high': 94.72000122070312,
#     'low': 92.51000213623047,
#     'open': 93.98999786376953,
#     'close': 93.73999786376953,
#     'volume': 68531500,
#     'adjclose': 88.33718872070312,
#     'formatted_date': '2016-04-29'},
#    {'date': 1462195800,
#     'high': 94.08000183105469,
#     'low': 92.4000015258789,
#     'open': 93.97000122070312,
#     'close': 93.63999938964844,
#     'volume': 48160100,
#     'adjclose': 88.24295043945312,
#     'formatted_date': '2016-05-02'},
#    {'date': 1462282200,
#     'high': 95.73999786376953,
#     'low': 93.68000030517578,
#     'open': 94.19999694824219,
#     'close': 95.18000030517578,
#     'volume': 56831300,
#     'adjclose': 89.6941909790039,
#     'formatted_date': '2016-05-03'},
#    {'date': 1462368600,
#     'high': 95.9000015258789,
#     'low': 93.81999969482422,
#     'open': 95.19999694824219,
#     'close': 94.19000244140625,
#     'volume': 41025500,
#     'adjclose': 88.7612533569336,
#     'formatted_date': '2016-05-04'},
#    {'date': 1462455000,
#     'high': 94.06999969482422,
#     'low': 92.68000030517578,
#     'open': 94.0,
#     'close': 93.23999786376953,
#     'volume': 35890500,
#     'adjclose': 88.4009780883789,
#     'formatted_date': '2016-05-05'},
#    {'date': 1462541400,
#     'high': 93.44999694824219,
#     'low': 91.8499984741211,
#     'open': 93.37000274658203,
#     'close': 92.72000122070312,
#     'volume': 43699900,
#     'adjclose': 87.907958984375,
#     'formatted_date': '2016-05-06'},
#    {'date': 1462800600,
#     'high': 93.7699966430664,
#     'low': 92.58999633789062,
#     'open': 93.0,
#     'close': 92.79000091552734,
#     'volume': 32936400,
#     'adjclose': 87.9743423461914,
#     'formatted_date': '2016-05-09'},
#    {'date': 1462887000,
#     'high': 93.56999969482422,
#     'low': 92.11000061035156,
#     'open': 93.33000183105469,
#     'close': 93.41999816894531,
#     'volume': 33686800,
#     'adjclose': 88.5716323852539,
#     'formatted_date': '2016-05-10'},
#    {'date': 1462973400,
#     'high': 93.56999969482422,
#     'low': 92.45999908447266,
#     'open': 93.4800033569336,
#     'close': 92.51000213623047,
#     'volume': 28719100,
#     'adjclose': 87.70886993408203,
#     'formatted_date': '2016-05-11'},
#    {'date': 1463059800,
#     'high': 92.77999877929688,
#     'low': 89.47000122070312,
#     'open': 92.72000122070312,
#     'close': 90.33999633789062,
#     'volume': 76314700,
#     'adjclose': 85.65148162841797,
#     'formatted_date': '2016-05-12'},
#    {'date': 1463146200,
#     'high': 91.66999816894531,
#     'low': 90.0,
#     'open': 90.0,
#     'close': 90.5199966430664,
#     'volume': 44392800,
#     'adjclose': 85.82213592529297,
#     'formatted_date': '2016-05-13'},
#    {'date': 1463405400,
#     'high': 94.38999938964844,
#     'low': 91.6500015258789,
#     'open': 92.38999938964844,
#     'close': 93.87999725341797,
#     'volume': 61259800,
#     'adjclose': 89.00775909423828,
#     'formatted_date': '2016-05-16'},
#    {'date': 1463491800,
#     'high': 94.69999694824219,
#     'low': 93.01000213623047,
#     'open': 94.55000305175781,
#     'close': 93.48999786376953,
#     'volume': 46916900,
#     'adjclose': 88.63799285888672,
#     'formatted_date': '2016-05-17'},
#    {'date': 1463578200,
#     'high': 95.20999908447266,
#     'low': 93.88999938964844,
#     'open': 94.16000366210938,
#     'close': 94.55999755859375,
#     'volume': 42062400,
#     'adjclose': 89.6524658203125,
#     'formatted_date': '2016-05-18'},
#    {'date': 1463664600,
#     'high': 94.63999938964844,
#     'low': 93.56999969482422,
#     'open': 94.63999938964844,
#     'close': 94.19999694824219,
#     'volume': 30442100,
#     'adjclose': 89.3111572265625,
#     'formatted_date': '2016-05-19'},
#    {'date': 1463751000,
#     'high': 95.43000030517578,
#     'low': 94.5199966430664,
#     'open': 94.63999938964844,
#     'close': 95.22000122070312,
#     'volume': 32026000,
#     'adjclose': 90.27822875976562,
#     'formatted_date': '2016-05-20'},
#    {'date': 1464010200,
#     'high': 97.19000244140625,
#     'low': 95.66999816894531,
#     'open': 95.87000274658203,
#     'close': 96.43000030517578,
#     'volume': 38018600,
#     'adjclose': 91.42542266845703,
#     'formatted_date': '2016-05-23'},
#    {'date': 1464096600,
#     'high': 98.08999633789062,
#     'low': 96.83999633789062,
#     'open': 97.22000122070312,
#     'close': 97.9000015258789,
#     'volume': 35140200,
#     'adjclose': 92.81913757324219,
#     'formatted_date': '2016-05-24'},
#    {'date': 1464183000,
#     'high': 99.73999786376953,
#     'low': 98.11000061035156,
#     'open': 98.66999816894531,
#     'close': 99.62000274658203,
#     'volume': 38168800,
#     'adjclose': 94.44985961914062,
#     'formatted_date': '2016-05-25'},
#    {'date': 1464269400,
#     'high': 100.7300033569336,
#     'low': 98.63999938964844,
#     'open': 99.68000030517578,
#     'close': 100.41000366210938,
#     'volume': 56331200,
#     'adjclose': 95.19886779785156,
#     'formatted_date': '2016-05-26'},
#    {'date': 1464355800,
#     'high': 100.47000122070312,
#     'low': 99.25,
#     'open': 99.44000244140625,
#     'close': 100.3499984741211,
#     'volume': 36341200,
#     'adjclose': 95.14198303222656,
#     'formatted_date': '2016-05-27'},
#    {'date': 1464701400,
#     'high': 100.4000015258789,
#     'low': 98.81999969482422,
#     'open': 99.5999984741211,
#     'close': 99.86000061035156,
#     'volume': 42307200,
#     'adjclose': 94.67741394042969,
#     'formatted_date': '2016-05-31'},
#    {'date': 1464787800,
#     'high': 99.54000091552734,
#     'low': 98.33000183105469,
#     'open': 99.0199966430664,
#     'close': 98.45999908447266,
#     'volume': 29173300,
#     'adjclose': 93.35006713867188,
#     'formatted_date': '2016-06-01'},
#    {'date': 1464874200,
#     'high': 97.83999633789062,
#     'low': 96.62999725341797,
#     'open': 97.5999984741211,
#     'close': 97.72000122070312,
#     'volume': 40191600,
#     'adjclose': 92.64846801757812,
#     'formatted_date': '2016-06-02'},
#    {'date': 1464960600,
#     'high': 98.2699966430664,
#     'low': 97.44999694824219,
#     'open': 97.79000091552734,
#     'close': 97.91999816894531,
#     'volume': 28504900,
#     'adjclose': 92.83809661865234,
#     'formatted_date': '2016-06-03'},
#    {'date': 1465219800,
#     'high': 101.88999938964844,
#     'low': 97.55000305175781,
#     'open': 97.98999786376953,
#     'close': 98.62999725341797,
#     'volume': 23292500,
#     'adjclose': 93.51124572753906,
#     'formatted_date': '2016-06-06'},
#    {'date': 1465306200,
#     'high': 99.87000274658203,
#     'low': 98.95999908447266,
#     'open': 99.25,
#     'close': 99.02999877929688,
#     'volume': 22409500,
#     'adjclose': 93.89048767089844,
#     'formatted_date': '2016-06-07'},
#    {'date': 1465392600,
#     'high': 99.55999755859375,
#     'low': 98.68000030517578,
#     'open': 99.0199966430664,
#     'close': 98.94000244140625,
#     'volume': 20848100,
#     'adjclose': 93.80516052246094,
#     'formatted_date': '2016-06-08'},
#    {'date': 1465479000,
#     'high': 99.98999786376953,
#     'low': 98.45999908447266,
#     'open': 98.5,
#     'close': 99.6500015258789,
#     'volume': 26601400,
#     'adjclose': 94.47831726074219,
#     'formatted_date': '2016-06-09'},
#    {'date': 1465565400,
#     'high': 99.3499984741211,
#     'low': 98.4800033569336,
#     'open': 98.52999877929688,
#     'close': 98.83000183105469,
#     'volume': 31712900,
#     'adjclose': 93.70087432861328,
#     'formatted_date': '2016-06-10'},
#    {'date': 1465824600,
#     'high': 99.12000274658203,
#     'low': 97.0999984741211,
#     'open': 98.69000244140625,
#     'close': 97.33999633789062,
#     'volume': 38020500,
#     'adjclose': 92.28819274902344,
#     'formatted_date': '2016-06-13'},
#    {'date': 1465911000,
#     'high': 98.4800033569336,
#     'low': 96.75,
#     'open': 97.31999969482422,
#     'close': 97.45999908447266,
#     'volume': 31931900,
#     'adjclose': 92.4019546508789,
#     'formatted_date': '2016-06-14'},
#    {'date': 1465997400,
#     'high': 98.41000366210938,
#     'low': 97.02999877929688,
#     'open': 97.81999969482422,
#     'close': 97.13999938964844,
#     'volume': 29445200,
#     'adjclose': 92.09856414794922,
#     'formatted_date': '2016-06-15'},
#    {'date': 1466083800,
#     'high': 97.75,
#     'low': 96.06999969482422,
#     'open': 96.44999694824219,
#     'close': 97.55000305175781,
# ...
#     'volume': 40396100,
#     'adjclose': 172.64404296875,
#     'formatted_date': '2019-06-03'},
#    {'date': 1559655000,
#     'high': 179.8300018310547,
#     'low': 174.52000427246094,
#     'open': 175.44000244140625,
#     'close': 179.63999938964844,
#     'volume': 30968000,
#     'adjclose': 178.96005249023438,
#     'formatted_date': '2019-06-04'},
#    {'date': 1559741400,
#     'high': 184.99000549316406,
#     'low': 181.13999938964844,
#     'open': 184.27999877929688,
#     'close': 182.5399932861328,
#     'volume': 29773400,
#     'adjclose': 181.84906005859375,
#     'formatted_date': '2019-06-05'},
#    {'date': 1559827800,
#     'high': 185.47000122070312,
#     'low': 182.14999389648438,
#     'open': 183.0800018310547,
#     'close': 185.22000122070312,
#     'volume': 22526300,
#     'adjclose': 184.51893615722656,
#     'formatted_date': '2019-06-06'},
#    {'date': 1559914200,
#     'high': 191.9199981689453,
#     'low': 185.77000427246094,
#     'open': 186.50999450683594,
#     'close': 190.14999389648438,
#     'volume': 30684400,
#     'adjclose': 189.43026733398438,
#     'formatted_date': '2019-06-07'},
#    {'date': 1560173400,
#     'high': 195.3699951171875,
#     'low': 191.6199951171875,
#     'open': 191.80999755859375,
#     'close': 192.5800018310547,
#     'volume': 26220900,
#     'adjclose': 191.85107421875,
#     'formatted_date': '2019-06-10'},
#    {'date': 1560259800,
#     'high': 196.0,
#     'low': 193.60000610351562,
#     'open': 194.86000061035156,
#     'close': 194.80999755859375,
#     'volume': 26932900,
#     'adjclose': 194.0726318359375,
#     'formatted_date': '2019-06-11'},
#    {'date': 1560346200,
#     'high': 195.97000122070312,
#     'low': 193.38999938964844,
#     'open': 193.9499969482422,
#     'close': 194.19000244140625,
#     'volume': 18253200,
#     'adjclose': 193.45498657226562,
#     'formatted_date': '2019-06-12'},
#    {'date': 1560432600,
#     'high': 196.7899932861328,
#     'low': 193.60000610351562,
#     'open': 194.6999969482422,
#     'close': 194.14999389648438,
#     'volume': 21674600,
#     'adjclose': 193.4151153564453,
#     'formatted_date': '2019-06-13'},
#    {'date': 1560519000,
#     'high': 193.58999633789062,
#     'low': 190.3000030517578,
#     'open': 191.5500030517578,
#     'close': 192.74000549316406,
#     'volume': 18761500,
#     'adjclose': 192.01046752929688,
#     'formatted_date': '2019-06-14'},
#    {'date': 1560778200,
#     'high': 194.9600067138672,
#     'low': 192.1699981689453,
#     'open': 192.89999389648438,
#     'close': 193.88999938964844,
#     'volume': 14669100,
#     'adjclose': 193.15611267089844,
#     'formatted_date': '2019-06-17'},
#    {'date': 1560864600,
#     'high': 200.2899932861328,
#     'low': 195.2100067138672,
#     'open': 196.0500030517578,
#     'close': 198.4499969482422,
#     'volume': 26551000,
#     'adjclose': 197.6988525390625,
#     'formatted_date': '2019-06-18'},
#    {'date': 1560951000,
#     'high': 199.8800048828125,
#     'low': 197.30999755859375,
#     'open': 199.67999267578125,
#     'close': 197.8699951171875,
#     'volume': 21124200,
#     'adjclose': 197.1210479736328,
#     'formatted_date': '2019-06-19'},
#    {'date': 1561037400,
#     'high': 200.61000061035156,
#     'low': 198.02999877929688,
#     'open': 200.3699951171875,
#     'close': 199.4600067138672,
#     'volume': 21514000,
#     'adjclose': 198.7050323486328,
#     'formatted_date': '2019-06-20'},
#    {'date': 1561123800,
#     'high': 200.85000610351562,
#     'low': 198.14999389648438,
#     'open': 198.8000030517578,
#     'close': 198.77999877929688,
#     'volume': 47800600,
#     'adjclose': 198.02760314941406,
#     'formatted_date': '2019-06-21'},
#    {'date': 1561383000,
#     'high': 200.16000366210938,
#     'low': 198.1699981689453,
#     'open': 198.5399932861328,
#     'close': 198.5800018310547,
#     'volume': 18220400,
#     'adjclose': 197.828369140625,
#     'formatted_date': '2019-06-24'},
#    {'date': 1561469400,
#     'high': 199.25999450683594,
#     'low': 195.2899932861328,
#     'open': 198.42999267578125,
#     'close': 195.57000732421875,
#     'volume': 21070300,
#     'adjclose': 194.8297576904297,
#     'formatted_date': '2019-06-25'},
#    {'date': 1561555800,
#     'high': 200.99000549316406,
#     'low': 197.35000610351562,
#     'open': 197.77000427246094,
#     'close': 199.8000030517578,
#     'volume': 26067500,
#     'adjclose': 199.0437469482422,
#     'formatted_date': '2019-06-26'},
#    {'date': 1561642200,
#     'high': 201.57000732421875,
#     'low': 199.57000732421875,
#     'open': 200.2899932861328,
#     'close': 199.74000549316406,
#     'volume': 20899700,
#     'adjclose': 198.98397827148438,
#     'formatted_date': '2019-06-27'},
#    {'date': 1561728600,
#     'high': 199.5,
#     'low': 197.0500030517578,
#     'open': 198.67999267578125,
#     'close': 197.9199981689453,
#     'volume': 31110600,
#     'adjclose': 197.1708526611328,
#     'formatted_date': '2019-06-28'},
#    {'date': 1561987800,
#     'high': 204.49000549316406,
#     'low': 200.64999389648438,
#     'open': 203.1699981689453,
#     'close': 201.5500030517578,
#     'volume': 27253000,
#     'adjclose': 200.78712463378906,
#     'formatted_date': '2019-07-01'},
#    {'date': 1562074200,
#     'high': 203.1300048828125,
#     'low': 201.36000061035156,
#     'open': 201.41000366210938,
#     'close': 202.72999572753906,
#     'volume': 16935200,
#     'adjclose': 201.962646484375,
#     'formatted_date': '2019-07-02'},
#    {'date': 1562160600,
#     'high': 204.44000244140625,
#     'low': 202.69000244140625,
#     'open': 203.27999877929688,
#     'close': 204.41000366210938,
#     'volume': 11362000,
#     'adjclose': 203.63629150390625,
#     'formatted_date': '2019-07-03'},
#    {'date': 1562333400,
#     'high': 205.0800018310547,
#     'low': 202.89999389648438,
#     'open': 203.35000610351562,
#     'close': 204.22999572753906,
#     'volume': 17265500,
#     'adjclose': 203.45697021484375,
#     'formatted_date': '2019-07-05'},
#    {'date': 1562592600,
#     'high': 201.39999389648438,
#     'low': 198.41000366210938,
#     'open': 200.80999755859375,
#     'close': 200.02000427246094,
#     'volume': 25338600,
#     'adjclose': 199.26290893554688,
#     'formatted_date': '2019-07-08'},
#    {'date': 1562679000,
#     'high': 201.50999450683594,
#     'low': 198.80999755859375,
#     'open': 199.1999969482422,
#     'close': 201.24000549316406,
#     'volume': 20578000,
#     'adjclose': 200.47830200195312,
#     'formatted_date': '2019-07-09'},
#    {'date': 1562765400,
#     'high': 203.72999572753906,
#     'low': 201.55999755859375,
#     'open': 201.85000610351562,
#     'close': 203.22999572753906,
#     'volume': 17897100,
#     'adjclose': 202.46075439453125,
#     'formatted_date': '2019-07-10'},
#    {'date': 1562851800,
#     'high': 204.38999938964844,
#     'low': 201.7100067138672,
#     'open': 203.30999755859375,
#     'close': 201.75,
#     'volume': 20191800,
#     'adjclose': 200.98635864257812,
#     'formatted_date': '2019-07-11'},
#    {'date': 1562938200,
#     'high': 204.0,
#     'low': 202.1999969482422,
#     'open': 202.4499969482422,
#     'close': 203.3000030517578,
#     'volume': 17595200,
#     'adjclose': 202.53050231933594,
#     'formatted_date': '2019-07-12'},
#    {'date': 1563197400,
#     'high': 205.8699951171875,
#     'low': 204.0,
#     'open': 204.08999633789062,
#     'close': 205.2100067138672,
#     'volume': 16947400,
#     'adjclose': 204.4332733154297,
#     'formatted_date': '2019-07-15'},
#    {'date': 1563283800,
#     'high': 206.11000061035156,
#     'low': 203.5,
#     'open': 204.58999633789062,
#     'close': 204.5,
#     'volume': 16866800,
#     'adjclose': 203.7259521484375,
#     'formatted_date': '2019-07-16'},
#    {'date': 1563370200,
#     'high': 205.08999633789062,
#     'low': 203.27000427246094,
#     'open': 204.0500030517578,
#     'close': 203.35000610351562,
#     'volume': 14107500,
#     'adjclose': 202.58030700683594,
#     'formatted_date': '2019-07-17'},
#    {'date': 1563456600,
#     'high': 205.8800048828125,
#     'low': 203.6999969482422,
#     'open': 204.0,
#     'close': 205.66000366210938,
#     'volume': 18540600,
#     'adjclose': 204.88156127929688,
#     'formatted_date': '2019-07-18'},
#    {'date': 1563543000,
#     'high': 206.5,
#     'low': 202.36000061035156,
#     'open': 205.7899932861328,
#     'close': 202.58999633789062,
#     'volume': 20929300,
#     'adjclose': 201.82318115234375,
#     'formatted_date': '2019-07-19'},
#    {'date': 1563802200,
#     'high': 207.22999572753906,
#     'low': 203.61000061035156,
#     'open': 203.64999389648438,
#     'close': 207.22000122070312,
#     'volume': 22277900,
#     'adjclose': 206.43565368652344,
#     'formatted_date': '2019-07-22'},
#    {'date': 1563888600,
#     'high': 208.91000366210938,
#     'low': 207.2899932861328,
#     'open': 208.4600067138672,
#     'close': 208.83999633789062,
#     'volume': 18355200,
#     'adjclose': 208.0495147705078,
#     'formatted_date': '2019-07-23'},
#    {'date': 1563975000,
#     'high': 209.14999389648438,
#     'low': 207.1699981689453,
#     'open': 207.6699981689453,
#     'close': 208.6699981689453,
#     'volume': 14991600,
#     'adjclose': 207.8801727294922,
#     'formatted_date': '2019-07-24'},
#    {'date': 1564061400,
#     'high': 209.24000549316406,
#     'low': 206.72999572753906,
#     'open': 208.88999938964844,
#     'close': 207.02000427246094,
#     'volume': 13909600,
#     'adjclose': 206.23641967773438,
#     'formatted_date': '2019-07-25'},
#    {'date': 1564147800,
#     'high': 209.72999572753906,
#     'low': 207.13999938964844,
#     'open': 207.47999572753906,
#     'close': 207.74000549316406,
#     'volume': 17618900,
#     'adjclose': 206.9536895751953,
#     'formatted_date': '2019-07-26'},
#    {'date': 1564407000,
#     'high': 210.63999938964844,
#     'low': 208.44000244140625,
#     'open': 208.4600067138672,
#     'close': 209.67999267578125,
#     'volume': 21673400,
#     'adjclose': 208.88633728027344,
#     'formatted_date': '2019-07-29'},
#    {'date': 1564493400,
#     'high': 210.16000366210938,
#     'low': 207.30999755859375,
#     'open': 208.75999450683594,
#     'close': 208.77999877929688,
#     'volume': 33935700,
#     'adjclose': 207.98974609375,
#     'formatted_date': '2019-07-30'},
#    {'date': 1564579800,
#     'high': 221.3699951171875,
#     'low': 211.3000030517578,
#     'open': 216.4199981689453,
#     'close': 213.0399932861328,
#     'volume': 69281400,
#     'adjclose': 212.23362731933594,
#     'formatted_date': '2019-07-31'},
#    {'date': 1564666200,
#     'high': 218.02999877929688,
#     'low': 206.74000549316406,
#     'open': 213.89999389648438,
#     'close': 208.42999267578125,
#     'volume': 54017900,
#     'adjclose': 207.6410675048828,
#     'formatted_date': '2019-08-01'},
#    {'date': 1564752600,
#     'high': 206.42999267578125,
#     'low': 201.6300048828125,
#     'open': 205.52999877929688,
#     'close': 204.02000427246094,
#     'volume': 40862100,
#     'adjclose': 203.24777221679688,
#     'formatted_date': '2019-08-02'},
#    {'date': 1565011800,
#     'high': 198.64999389648438,
#     'low': 192.5800018310547,
#     'open': 197.99000549316406,
#     'close': 193.33999633789062,
#     'volume': 52393000,
#     'adjclose': 192.60818481445312,
#     'formatted_date': '2019-08-05'},
#    {'date': 1565098200,
#     'high': 198.07000732421875,
#     'low': 194.0399932861328,
#     'open': 196.30999755859375,
#     'close': 197.0,
#     'volume': 35824800,
#     'adjclose': 196.25433349609375,
#     'formatted_date': '2019-08-06'},
#    {'date': 1565184600,
#     'high': 199.55999755859375,
#     'low': 193.82000732421875,
#     'open': 195.41000366210938,
#     'close': 199.0399932861328,
#     'volume': 33364400,
#     'adjclose': 198.28660583496094,
#     'formatted_date': '2019-08-07'},
#    {'date': 1565271000,
#     'high': 203.52999877929688,
#     'low': 199.38999938964844,
#     'open': 200.1999969482422,
#     'close': 203.42999267578125,
#     'volume': 27009500,
#     'adjclose': 202.6599884033203,
#     'formatted_date': '2019-08-08'},
#    {'date': 1565357400,
#     'high': 202.75999450683594,
#     'low': 199.2899932861328,
#     'open': 201.3000030517578,
#     'close': 200.99000549316406,
#     'volume': 24619700,
#     'adjclose': 200.99000549316406,
#     'formatted_date': '2019-08-09'},
#    {'date': 1565616600,
#     'high': 202.0500030517578,
#     'low': 199.14999389648438,
#     'open': 199.6199951171875,
#     'close': 200.47999572753906,
#     'volume': 22481900,
#     'adjclose': 200.47999572753906,
#     'formatted_date': '2019-08-12'},
#    {'date': 1565703000,
#     'high': 212.13999938964844,
#     'low': 200.47999572753906,
#     'open': 201.02000427246094,
#     'close': 208.97000122070312,
#     'volume': 47218500,
#     'adjclose': 208.97000122070312,
#     'formatted_date': '2019-08-13'},
#    {'date': 1565789400,
#     'high': 206.44000244140625,
#     'low': 202.58999633789062,
#     'open': 203.16000366210938,
#     'close': 202.75,
#     'volume': 36547400,
#     'adjclose': 202.75,
#     'formatted_date': '2019-08-14'},
#    {'date': 1565875800,
#     'high': 205.13999938964844,
#     'low': 199.6699981689453,
#     'open': 203.4600067138672,
#     'close': 201.74000549316406,
#     'volume': 27227400,
#     'adjclose': 201.74000549316406,
#     'formatted_date': '2019-08-15'},
#    {'date': 1565962200,
#     'high': 207.16000366210938,
#     'low': 203.83999633789062,
#     'open': 204.27999877929688,
#     'close': 206.5,
#     'volume': 27620400,
#     'adjclose': 206.5,
#     'formatted_date': '2019-08-16'},
#    {'date': 1566221400,
#     'high': 212.72999572753906,
#     'low': 210.02999877929688,
#     'open': 210.6199951171875,
#     'close': 210.35000610351562,
#     'volume': 24413600,
#     'adjclose': 210.35000610351562,
#     'formatted_date': '2019-08-19'},
#    {'date': 1566307800,
#     'high': 213.35000610351562,
#     'low': 210.32000732421875,
#     'open': 210.8800048828125,
#     'close': 210.36000061035156,
#     'volume': 26884300,
#     'adjclose': 210.36000061035156,
#     'formatted_date': '2019-08-20'},
#    {'date': 1566394200,
#     'high': 213.64999389648438,
#     'low': 211.60000610351562,
#     'open': 212.99000549316406,
#     'close': 212.63999938964844,
#     'volume': 21535400,
#     'adjclose': 212.63999938964844,
#     'formatted_date': '2019-08-21'},
#    {'date': 1566480600,
#     'high': 214.44000244140625,
#     'low': 210.75,
#     'open': 213.19000244140625,
#     'close': 212.4600067138672,
#     'volume': 22253700,
#     'adjclose': 212.4600067138672,
#     'formatted_date': '2019-08-22'},
#    {'date': 1566567000,
#     'high': 212.0500030517578,
#     'low': 201.0,
#     'open': 209.42999267578125,
#     'close': 202.63999938964844,
#     'volume': 46818000,
#     'adjclose': 202.63999938964844,
#     'formatted_date': '2019-08-23'},
#    {'date': 1566826200,
#     'high': 207.19000244140625,
#     'low': 205.05999755859375,
#     'open': 205.86000061035156,
#     'close': 206.49000549316406,
#     'volume': 26043600,
#     'adjclose': 206.49000549316406,
#     'formatted_date': '2019-08-26'},
#    {'date': 1566912600,
#     'high': 208.5500030517578,
#     'low': 203.52999877929688,
#     'open': 207.86000061035156,
#     'close': 204.16000366210938,
#     'volume': 25873300,
#     'adjclose': 204.16000366210938,
#     'formatted_date': '2019-08-27'},
#    {'date': 1566999000,
#     'high': 205.72000122070312,
#     'low': 203.32000732421875,
#     'open': 204.10000610351562,
#     'close': 205.52999877929688,
#     'volume': 15938800,
#     'adjclose': 205.52999877929688,
#     'formatted_date': '2019-08-28'},
#    {'date': 1567085400,
#     'high': 209.32000732421875,
#     'low': 206.66000366210938,
#     'open': 208.5,
#     'close': 209.00999450683594,
#     'volume': 20990500,
#     'adjclose': 209.00999450683594,
#     'formatted_date': '2019-08-29'},
#    {'date': 1567171800,
#     'high': 210.4499969482422,
#     'low': 207.1999969482422,
#     'open': 210.16000366210938,
#     'close': 208.74000549316406,
#     'volume': 21143400,
#     'adjclose': 208.74000549316406,
#     'formatted_date': '2019-08-30'},
#    {'date': 1567517400,
#     'high': 206.97999572753906,
#     'low': 204.22000122070312,
#     'open': 206.42999267578125,
#     'close': 205.6999969482422,
#     'volume': 20023000,
#     'adjclose': 205.6999969482422,
#     'formatted_date': '2019-09-03'},
#    {'date': 1567603800,
#     'high': 209.47999572753906,
#     'low': 207.32000732421875,
#     'open': 208.38999938964844,
#     'close': 209.19000244140625,
#     'volume': 19188100,
#     'adjclose': 209.19000244140625,
#     'formatted_date': '2019-09-04'},
#    ...]}}

# %% [markdown]
# ### Normalize

# %%
stock = json_normalize(historical_stock_prices)
stock.head()
# Out:
#   AAPL.currency  AAPL.eventsData.dividends.2015-11-05.amount  \
# 0           USD                                         0.52
#
#    AAPL.eventsData.dividends.2015-11-05.date  \
# 0                                 1446733800
#
#   AAPL.eventsData.dividends.2015-11-05.formatted_date  \
# 0                                         2015-11-05
#
#    AAPL.eventsData.dividends.2016-02-04.amount  \
# 0                                         0.52
#
#    AAPL.eventsData.dividends.2016-02-04.date  \
# 0                                 1454596200
#
#   AAPL.eventsData.dividends.2016-02-04.formatted_date  \
# 0                                         2016-02-04
#
#    AAPL.eventsData.dividends.2016-05-05.amount  \
# 0                                         0.57
#
#    AAPL.eventsData.dividends.2016-05-05.date  \
# 0                                 1462455000
#
#   AAPL.eventsData.dividends.2016-05-05.formatted_date  \
# 0                                         2016-05-05
#
#             ...             AAPL.eventsData.dividends.2019-05-10.date  \
# 0           ...                                            1557495000
#
#    AAPL.eventsData.dividends.2019-05-10.formatted_date  \
# 0                                         2019-05-10
#
#   AAPL.eventsData.dividends.2019-08-09.amount  \
# 0                                        0.77
#
#    AAPL.eventsData.dividends.2019-08-09.date  \
# 0                                 1565357400
#
#    AAPL.eventsData.dividends.2019-08-09.formatted_date  \
# 0                                         2019-08-09
#
#   AAPL.firstTradeDate.date  AAPL.firstTradeDate.formatted_date  \
# 0                345459600                          1980-12-12
#
#    AAPL.instrumentType                                        AAPL.prices  \
# 0               EQUITY  [{'date': 1442323800, 'high': 116.529998779296...
#
#    AAPL.timeZone.gmtOffset
# 0                   -14400
#
# [1 rows x 54 columns]

# %%
prices = stock['AAPL.prices']
prices[0]
# Out:
# [{'date': 1442323800,
#   'high': 116.52999877929688,
#   'low': 114.41999816894531,
#   'open': 115.93000030517578,
#   'close': 116.27999877929688,
#   'volume': 43341200,
#   'adjclose': 108.52214813232422,
#   'formatted_date': '2015-09-15'},
#  {'date': 1442410200,
#   'high': 116.54000091552734,
#   'low': 115.44000244140625,
#   'open': 116.25,
#   'close': 116.41000366210938,
#   'volume': 37173500,
#   'adjclose': 108.64347839355469,
#   'formatted_date': '2015-09-16'},
#  {'date': 1442496600,
#   'high': 116.48999786376953,
#   'low': 113.72000122070312,
#   'open': 115.66000366210938,
#   'close': 113.91999816894531,
#   'volume': 64112600,
#   'adjclose': 106.31961059570312,
#   'formatted_date': '2015-09-17'},
#  {'date': 1442583000,
#   'high': 114.30000305175781,
#   'low': 111.87000274658203,
#   'open': 112.20999908447266,
#   'close': 113.44999694824219,
#   'volume': 74285300,
#   'adjclose': 105.8809585571289,
#   'formatted_date': '2015-09-18'},
#  {'date': 1442842200,
#   'high': 115.37000274658203,
#   'low': 113.66000366210938,
#   'open': 113.66999816894531,
#   'close': 115.20999908447266,
#   'volume': 50222000,
#   'adjclose': 107.52354431152344,
#   'formatted_date': '2015-09-21'},
#  {'date': 1442928600,
#   'high': 114.18000030517578,
#   'low': 112.5199966430664,
#   'open': 113.37999725341797,
#   'close': 113.4000015258789,
#   'volume': 50346200,
#   'adjclose': 105.83430480957031,
#   'formatted_date': '2015-09-22'},
#  {'date': 1443015000,
#   'high': 114.72000122070312,
#   'low': 113.30000305175781,
#   'open': 113.62999725341797,
#   'close': 114.31999969482422,
#   'volume': 35756700,
#   'adjclose': 106.69291687011719,
#   'formatted_date': '2015-09-23'},
#  {'date': 1443101400,
#   'high': 115.5,
#   'low': 112.37000274658203,
#   'open': 113.25,
#   'close': 115.0,
#   'volume': 50219500,
#   'adjclose': 107.32756805419922,
#   'formatted_date': '2015-09-24'},
#  {'date': 1443187800,
#   'high': 116.69000244140625,
#   'low': 114.0199966430664,
#   'open': 116.44000244140625,
#   'close': 114.70999908447266,
#   'volume': 56151900,
#   'adjclose': 107.05689239501953,
#   'formatted_date': '2015-09-25'},
#  {'date': 1443447000,
#   'high': 114.56999969482422,
#   'low': 112.44000244140625,
#   'open': 113.8499984741211,
#   'close': 112.44000244140625,
#   'volume': 52109000,
#   'adjclose': 104.93833923339844,
#   'formatted_date': '2015-09-28'},
#  {'date': 1443533400,
#   'high': 113.51000213623047,
#   'low': 107.86000061035156,
#   'open': 112.83000183105469,
#   'close': 109.05999755859375,
#   'volume': 73365400,
#   'adjclose': 101.78384399414062,
#   'formatted_date': '2015-09-29'},
#  {'date': 1443619800,
#   'high': 111.54000091552734,
#   'low': 108.7300033569336,
#   'open': 110.16999816894531,
#   'close': 110.30000305175781,
#   'volume': 66473000,
#   'adjclose': 102.94112396240234,
#   'formatted_date': '2015-09-30'},
#  {'date': 1443706200,
#   'high': 109.62000274658203,
#   'low': 107.30999755859375,
#   'open': 109.06999969482422,
#   'close': 109.58000183105469,
#   'volume': 63929100,
#   'adjclose': 102.26915740966797,
#   'formatted_date': '2015-10-01'},
#  {'date': 1443792600,
#   'high': 111.01000213623047,
#   'low': 107.55000305175781,
#   'open': 108.01000213623047,
#   'close': 110.37999725341797,
#   'volume': 58019800,
#   'adjclose': 103.01578521728516,
#   'formatted_date': '2015-10-02'},
#  {'date': 1444051800,
#   'high': 111.37000274658203,
#   'low': 109.06999969482422,
#   'open': 109.87999725341797,
#   'close': 110.77999877929688,
#   'volume': 52064700,
#   'adjclose': 103.38910675048828,
#   'formatted_date': '2015-10-05'},
#  {'date': 1444138200,
#   'high': 111.73999786376953,
#   'low': 109.7699966430664,
#   'open': 110.62999725341797,
#   'close': 111.30999755859375,
#   'volume': 48196800,
#   'adjclose': 103.88373565673828,
#   'formatted_date': '2015-10-06'},
#  {'date': 1444224600,
#   'high': 111.7699966430664,
#   'low': 109.41000366210938,
#   'open': 111.73999786376953,
#   'close': 110.77999877929688,
#   'volume': 46765600,
#   'adjclose': 103.38910675048828,
#   'formatted_date': '2015-10-07'},
#  {'date': 1444311000,
#   'high': 110.19000244140625,
#   'low': 108.20999908447266,
#   'open': 110.19000244140625,
#   'close': 109.5,
#   'volume': 61979600,
#   'adjclose': 102.1944808959961,
#   'formatted_date': '2015-10-08'},
#  {'date': 1444397400,
#   'high': 112.27999877929688,
#   'low': 109.48999786376953,
#   'open': 110.0,
#   'close': 112.12000274658203,
#   'volume': 52766100,
#   'adjclose': 104.63971710205078,
#   'formatted_date': '2015-10-09'},
#  {'date': 1444656600,
#   'high': 112.75,
#   'low': 111.44000244140625,
#   'open': 112.7300033569336,
#   'close': 111.5999984741211,
#   'volume': 30467200,
#   'adjclose': 104.15436553955078,
#   'formatted_date': '2015-10-12'},
#  {'date': 1444743000,
#   'high': 112.44999694824219,
#   'low': 110.68000030517578,
#   'open': 110.81999969482422,
#   'close': 111.79000091552734,
#   'volume': 33049300,
#   'adjclose': 104.33171081542969,
#   'formatted_date': '2015-10-13'},
#  {'date': 1444829400,
#   'high': 111.5199966430664,
#   'low': 109.55999755859375,
#   'open': 111.29000091552734,
#   'close': 110.20999908447266,
#   'volume': 44462400,
#   'adjclose': 102.85713195800781,
#   'formatted_date': '2015-10-14'},
#  {'date': 1444915800,
#   'high': 112.0999984741211,
#   'low': 110.48999786376953,
#   'open': 110.93000030517578,
#   'close': 111.86000061035156,
#   'volume': 37673500,
#   'adjclose': 104.39704895019531,
#   'formatted_date': '2015-10-15'},
#  {'date': 1445002200,
#   'high': 112.0,
#   'low': 110.52999877929688,
#   'open': 111.77999877929688,
#   'close': 111.04000091552734,
#   'volume': 39232600,
#   'adjclose': 103.63176727294922,
#   'formatted_date': '2015-10-16'},
#  {'date': 1445261400,
#   'high': 111.75,
#   'low': 110.11000061035156,
#   'open': 110.80000305175781,
#   'close': 111.7300033569336,
#   'volume': 29759200,
#   'adjclose': 104.27571105957031,
#   'formatted_date': '2015-10-19'},
#  {'date': 1445347800,
#   'high': 114.16999816894531,
#   'low': 110.81999969482422,
#   'open': 111.33999633789062,
#   'close': 113.7699966430664,
#   'volume': 48967800,
#   'adjclose': 106.17964172363281,
#   'formatted_date': '2015-10-20'},
#  {'date': 1445434200,
#   'high': 115.58000183105469,
#   'low': 113.69999694824219,
#   'open': 114.0,
#   'close': 113.76000213623047,
#   'volume': 41795200,
#   'adjclose': 106.17029571533203,
#   'formatted_date': '2015-10-21'},
#  {'date': 1445520600,
#   'high': 115.5,
#   'low': 114.0999984741211,
#   'open': 114.33000183105469,
#   'close': 115.5,
#   'volume': 41654100,
#   'adjclose': 107.794189453125,
#   'formatted_date': '2015-10-22'},
#  {'date': 1445607000,
#   'high': 119.2300033569336,
#   'low': 116.33000183105469,
#   'open': 116.69999694824219,
#   'close': 119.08000183105469,
#   'volume': 59366900,
#   'adjclose': 111.1353530883789,
#   'formatted_date': '2015-10-23'},
#  {'date': 1445866200,
#   'high': 118.12999725341797,
#   'low': 114.91999816894531,
#   'open': 118.08000183105469,
#   'close': 115.27999877929688,
#   'volume': 66333800,
#   'adjclose': 107.5888671875,
#   'formatted_date': '2015-10-26'},
#  {'date': 1445952600,
#   'high': 116.54000091552734,
#   'low': 113.98999786376953,
#   'open': 115.4000015258789,
#   'close': 114.55000305175781,
#   'volume': 69884400,
#   'adjclose': 106.9075698852539,
#   'formatted_date': '2015-10-27'},
#  {'date': 1446039000,
#   'high': 119.30000305175781,
#   'low': 116.05999755859375,
#   'open': 116.93000030517578,
#   'close': 119.2699966430664,
#   'volume': 85551400,
#   'adjclose': 111.31266784667969,
#   'formatted_date': '2015-10-28'},
#  {'date': 1446125400,
#   'high': 120.69000244140625,
#   'low': 118.2699966430664,
#   'open': 118.69999694824219,
#   'close': 120.52999877929688,
#   'volume': 51227300,
#   'adjclose': 112.48859405517578,
#   'formatted_date': '2015-10-29'},
#  {'date': 1446211800,
#   'high': 121.22000122070312,
#   'low': 119.44999694824219,
#   'open': 120.98999786376953,
#   'close': 119.5,
#   'volume': 49365300,
#   'adjclose': 111.52732849121094,
#   'formatted_date': '2015-10-30'},
#  {'date': 1446474600,
#   'high': 121.36000061035156,
#   'low': 119.61000061035156,
#   'open': 120.80000305175781,
#   'close': 121.18000030517578,
#   'volume': 32203300,
#   'adjclose': 113.09524536132812,
#   'formatted_date': '2015-11-02'},
#  {'date': 1446561000,
#   'high': 123.48999786376953,
#   'low': 120.69999694824219,
#   'open': 120.79000091552734,
#   'close': 122.56999969482422,
#   'volume': 45519000,
#   'adjclose': 114.39250183105469,
#   'formatted_date': '2015-11-03'},
#  {'date': 1446647400,
#   'high': 123.81999969482422,
#   'low': 121.62000274658203,
#   'open': 123.12999725341797,
#   'close': 122.0,
#   'volume': 44886100,
#   'adjclose': 113.86053466796875,
#   'formatted_date': '2015-11-04'},
#  {'date': 1446733800,
#   'high': 122.69000244140625,
#   'low': 120.18000030517578,
#   'open': 121.8499984741211,
#   'close': 120.91999816894531,
#   'volume': 39552700,
#   'adjclose': 113.33565521240234,
#   'formatted_date': '2015-11-05'},
#  {'date': 1446820200,
#   'high': 121.80999755859375,
#   'low': 120.62000274658203,
#   'open': 121.11000061035156,
#   'close': 121.05999755859375,
#   'volume': 33042300,
#   'adjclose': 113.46687316894531,
#   'formatted_date': '2015-11-06'},
#  {'date': 1447079400,
#   'high': 121.80999755859375,
#   'low': 120.05000305175781,
#   'open': 120.95999908447266,
#   'close': 120.56999969482422,
#   'volume': 33871400,
#   'adjclose': 113.00760650634766,
#   'formatted_date': '2015-11-09'},
#  {'date': 1447165800,
#   'high': 118.06999969482422,
#   'low': 116.05999755859375,
#   'open': 116.9000015258789,
#   'close': 116.7699966430664,
#   'volume': 59127900,
#   'adjclose': 109.44595336914062,
#   'formatted_date': '2015-11-10'},
#  {'date': 1447252200,
#   'high': 117.41999816894531,
#   'low': 115.20999908447266,
#   'open': 116.37000274658203,
#   'close': 116.11000061035156,
#   'volume': 45218000,
#   'adjclose': 108.82733917236328,
#   'formatted_date': '2015-11-11'},
#  {'date': 1447338600,
#   'high': 116.81999969482422,
#   'low': 115.6500015258789,
#   'open': 116.26000213623047,
#   'close': 115.72000122070312,
#   'volume': 32525600,
#   'adjclose': 108.46180725097656,
#   'formatted_date': '2015-11-12'},
#  {'date': 1447425000,
#   'high': 115.56999969482422,
#   'low': 112.2699966430664,
#   'open': 115.19999694824219,
#   'close': 112.33999633789062,
#   'volume': 45812400,
#   'adjclose': 105.29380798339844,
#   'formatted_date': '2015-11-13'},
#  {'date': 1447684200,
#   'high': 114.23999786376953,
#   'low': 111.0,
#   'open': 111.37999725341797,
#   'close': 114.18000030517578,
#   'volume': 38106700,
#   'adjclose': 107.01840209960938,
#   'formatted_date': '2015-11-16'},
#  {'date': 1447770600,
#   'high': 115.05000305175781,
#   'low': 113.31999969482422,
#   'open': 114.91999816894531,
#   'close': 113.69000244140625,
#   'volume': 27616900,
#   'adjclose': 106.55913543701172,
#   'formatted_date': '2015-11-17'},
#  {'date': 1447857000,
#   'high': 117.48999786376953,
#   'low': 115.5,
#   'open': 115.76000213623047,
#   'close': 117.29000091552734,
#   'volume': 46674700,
#   'adjclose': 109.93334197998047,
#   'formatted_date': '2015-11-18'},
#  {'date': 1447943400,
#   'high': 119.75,
#   'low': 116.76000213623047,
#   'open': 117.63999938964844,
#   'close': 118.77999877929688,
#   'volume': 43295800,
#   'adjclose': 111.32989501953125,
#   'formatted_date': '2015-11-19'},
#  {'date': 1448029800,
#   'high': 119.91999816894531,
#   'low': 118.8499984741211,
#   'open': 119.19999694824219,
#   'close': 119.30000305175781,
#   'volume': 34287100,
#   'adjclose': 111.8172607421875,
#   'formatted_date': '2015-11-20'},
#  {'date': 1448289000,
#   'high': 119.7300033569336,
#   'low': 117.33999633789062,
#   'open': 119.2699966430664,
#   'close': 117.75,
#   'volume': 32482500,
#   'adjclose': 110.36449432373047,
#   'formatted_date': '2015-11-23'},
#  {'date': 1448375400,
#   'high': 119.3499984741211,
#   'low': 117.12000274658203,
#   'open': 117.33000183105469,
#   'close': 118.87999725341797,
#   'volume': 42803200,
#   'adjclose': 111.42359924316406,
#   'formatted_date': '2015-11-24'},
#  {'date': 1448461800,
#   'high': 119.2300033569336,
#   'low': 117.91999816894531,
#   'open': 119.20999908447266,
#   'close': 118.02999877929688,
#   'volume': 21388300,
#   'adjclose': 110.62692260742188,
#   'formatted_date': '2015-11-25'},
#  {'date': 1448634600,
#   'high': 118.41000366210938,
#   'low': 117.5999984741211,
#   'open': 118.29000091552734,
#   'close': 117.80999755859375,
#   'volume': 13046400,
#   'adjclose': 110.42073059082031,
#   'formatted_date': '2015-11-27'},
#  {'date': 1448893800,
#   'high': 119.41000366210938,
#   'low': 117.75,
#   'open': 117.98999786376953,
#   'close': 118.30000305175781,
#   'volume': 39180300,
#   'adjclose': 110.87999725341797,
#   'formatted_date': '2015-11-30'},
#  {'date': 1448980200,
#   'high': 118.80999755859375,
#   'low': 116.86000061035156,
#   'open': 118.75,
#   'close': 117.33999633789062,
#   'volume': 34852400,
#   'adjclose': 109.98018646240234,
#   'formatted_date': '2015-12-01'},
#  {'date': 1449066600,
#   'high': 118.11000061035156,
#   'low': 116.08000183105469,
#   'open': 117.33999633789062,
#   'close': 116.27999877929688,
#   'volume': 33386600,
#   'adjclose': 108.98667907714844,
#   'formatted_date': '2015-12-02'},
#  {'date': 1449153000,
#   'high': 116.79000091552734,
#   'low': 114.22000122070312,
#   'open': 116.55000305175781,
#   'close': 115.19999694824219,
#   'volume': 41569500,
#   'adjclose': 107.97441864013672,
#   'formatted_date': '2015-12-03'},
#  {'date': 1449239400,
#   'high': 119.25,
#   'low': 115.11000061035156,
#   'open': 115.29000091552734,
#   'close': 119.02999877929688,
#   'volume': 57777000,
#   'adjclose': 111.56419372558594,
#   'formatted_date': '2015-12-04'},
#  {'date': 1449498600,
#   'high': 119.86000061035156,
#   'low': 117.80999755859375,
#   'open': 118.9800033569336,
#   'close': 118.27999877929688,
#   'volume': 32084200,
#   'adjclose': 110.86124420166016,
#   'formatted_date': '2015-12-07'},
#  {'date': 1449585000,
#   'high': 118.5999984741211,
#   'low': 116.86000061035156,
#   'open': 117.5199966430664,
#   'close': 118.2300033569336,
#   'volume': 34309500,
#   'adjclose': 110.81437683105469,
#   'formatted_date': '2015-12-08'},
#  {'date': 1449671400,
#   'high': 117.69000244140625,
#   'low': 115.08000183105469,
#   'open': 117.63999938964844,
#   'close': 115.62000274658203,
#   'volume': 46361400,
#   'adjclose': 108.36808013916016,
#   'formatted_date': '2015-12-09'},
#  {'date': 1449757800,
#   'high': 116.94000244140625,
#   'low': 115.51000213623047,
#   'open': 116.04000091552734,
#   'close': 116.16999816894531,
#   'volume': 29212700,
#   'adjclose': 108.88358306884766,
#   'formatted_date': '2015-12-10'},
#  {'date': 1449844200,
#   'high': 115.38999938964844,
#   'low': 112.8499984741211,
#   'open': 115.19000244140625,
#   'close': 113.18000030517578,
#   'volume': 46886200,
#   'adjclose': 106.08112335205078,
#   'formatted_date': '2015-12-11'},
#  {'date': 1450103400,
#   'high': 112.68000030517578,
#   'low': 109.79000091552734,
#   'open': 112.18000030517578,
#   'close': 112.4800033569336,
#   'volume': 64318700,
#   'adjclose': 105.4250259399414,
#   'formatted_date': '2015-12-14'},
#  {'date': 1450189800,
#   'high': 112.80000305175781,
#   'low': 110.3499984741211,
#   'open': 111.94000244140625,
#   'close': 110.48999786376953,
#   'volume': 53323100,
#   'adjclose': 103.55984497070312,
#   'formatted_date': '2015-12-15'},
#  {'date': 1450276200,
#   'high': 111.98999786376953,
#   'low': 108.80000305175781,
#   'open': 111.06999969482422,
#   'close': 111.33999633789062,
#   'volume': 56238500,
#   'adjclose': 104.35651397705078,
#   'formatted_date': '2015-12-16'},
#  {'date': 1450362600,
#   'high': 112.25,
#   'low': 108.9800033569336,
#   'open': 112.0199966430664,
#   'close': 108.9800033569336,
#   'volume': 44772800,
#   'adjclose': 102.1445541381836,
#   'formatted_date': '2015-12-17'},
#  {'date': 1450449000,
#   'high': 109.5199966430664,
#   'low': 105.80999755859375,
#   'open': 108.91000366210938,
#   'close': 106.02999877929688,
#   'volume': 96453300,
#   'adjclose': 99.37958526611328,
#   'formatted_date': '2015-12-18'},
#  {'date': 1450708200,
#   'high': 107.37000274658203,
#   'low': 105.56999969482422,
#   'open': 107.27999877929688,
#   'close': 107.33000183105469,
#   'volume': 47590600,
#   'adjclose': 100.5980453491211,
#   'formatted_date': '2015-12-21'},
#  {'date': 1450794600,
#   'high': 107.72000122070312,
#   'low': 106.44999694824219,
#   'open': 107.4000015258789,
#   'close': 107.2300033569336,
#   'volume': 32789400,
#   'adjclose': 100.50433349609375,
#   'formatted_date': '2015-12-22'},
#  {'date': 1450881000,
#   'high': 108.8499984741211,
#   'low': 107.19999694824219,
#   'open': 107.2699966430664,
#   'close': 108.61000061035156,
#   'volume': 32657400,
#   'adjclose': 101.79776000976562,
#   'formatted_date': '2015-12-23'},
#  {'date': 1450967400,
#   'high': 109.0,
#   'low': 107.94999694824219,
#   'open': 109.0,
#   'close': 108.02999877929688,
#   'volume': 13570400,
#   'adjclose': 101.25414276123047,
#   'formatted_date': '2015-12-24'},
#  {'date': 1451313000,
#   'high': 107.69000244140625,
#   'low': 106.18000030517578,
#   'open': 107.58999633789062,
#   'close': 106.81999969482422,
#   'volume': 26704200,
#   'adjclose': 100.12003326416016,
#   'formatted_date': '2015-12-28'},
#  {'date': 1451399400,
#   'high': 109.43000030517578,
#   'low': 106.86000061035156,
#   'open': 106.95999908447266,
#   'close': 108.73999786376953,
#   'volume': 30931200,
#   'adjclose': 101.91960906982422,
#   'formatted_date': '2015-12-29'},
#  {'date': 1451485800,
#   'high': 108.69999694824219,
#   'low': 107.18000030517578,
#   'open': 108.58000183105469,
#   'close': 107.31999969482422,
#   'volume': 25213800,
#   'adjclose': 100.58867645263672,
#   'formatted_date': '2015-12-30'},
#  {'date': 1451572200,
#   'high': 107.02999877929688,
#   'low': 104.81999969482422,
#   'open': 107.01000213623047,
#   'close': 105.26000213623047,
#   'volume': 40912300,
#   'adjclose': 98.65788269042969,
#   'formatted_date': '2015-12-31'},
#  {'date': 1451917800,
#   'high': 105.37000274658203,
#   'low': 102.0,
#   'open': 102.61000061035156,
#   'close': 105.3499984741211,
#   'volume': 67649400,
#   'adjclose': 98.74224853515625,
#   'formatted_date': '2016-01-04'},
#  {'date': 1452004200,
#   'high': 105.8499984741211,
#   'low': 102.41000366210938,
#   'open': 105.75,
#   'close': 102.70999908447266,
#   'volume': 55791000,
#   'adjclose': 96.26781463623047,
#   'formatted_date': '2016-01-05'},
#  {'date': 1452090600,
#   'high': 102.37000274658203,
#   'low': 99.87000274658203,
#   'open': 100.55999755859375,
#   'close': 100.69999694824219,
#   'volume': 68457400,
#   'adjclose': 94.3838882446289,
#   'formatted_date': '2016-01-06'},
#  {'date': 1452177000,
#   'high': 100.12999725341797,
#   'low': 96.43000030517578,
#   'open': 98.68000030517578,
#   'close': 96.44999694824219,
#   'volume': 81094400,
#   'adjclose': 90.40046691894531,
#   'formatted_date': '2016-01-07'},
#  {'date': 1452263400,
#   'high': 99.11000061035156,
#   'low': 96.76000213623047,
#   'open': 98.55000305175781,
#   'close': 96.95999908447266,
#   'volume': 70798000,
#   'adjclose': 90.87847900390625,
#   'formatted_date': '2016-01-08'},
#  {'date': 1452522600,
#   'high': 99.05999755859375,
#   'low': 97.33999633789062,
#   'open': 98.97000122070312,
#   'close': 98.52999877929688,
#   'volume': 49739400,
#   'adjclose': 92.35000610351562,
#   'formatted_date': '2016-01-11'},
#  {'date': 1452609000,
#   'high': 100.69000244140625,
#   'low': 98.83999633789062,
#   'open': 100.55000305175781,
#   'close': 99.95999908447266,
#   'volume': 49154200,
#   'adjclose': 93.69029998779297,
#   'formatted_date': '2016-01-12'},
#  {'date': 1452695400,
#   'high': 101.19000244140625,
#   'low': 97.30000305175781,
#   'open': 100.31999969482422,
#   'close': 97.38999938964844,
#   'volume': 62439600,
#   'adjclose': 91.281494140625,
#   'formatted_date': '2016-01-13'},
#  {'date': 1452781800,
#   'high': 100.4800033569336,
#   'low': 95.73999786376953,
#   'open': 97.95999908447266,
#   'close': 99.5199966430664,
#   'volume': 63170100,
#   'adjclose': 93.27791595458984,
#   'formatted_date': '2016-01-14'},
#  {'date': 1452868200,
#   'high': 97.70999908447266,
#   'low': 95.36000061035156,
#   'open': 96.19999694824219,
#   'close': 97.12999725341797,
#   'volume': 79833900,
#   'adjclose': 91.03781127929688,
#   'formatted_date': '2016-01-15'},
#  {'date': 1453213800,
#   'high': 98.6500015258789,
#   'low': 95.5,
#   'open': 98.41000366210938,
#   'close': 96.66000366210938,
#   'volume': 53087700,
#   'adjclose': 90.5972900390625,
#   'formatted_date': '2016-01-19'},
#  {'date': 1453300200,
#   'high': 98.19000244140625,
#   'low': 93.41999816894531,
#   'open': 95.0999984741211,
#   'close': 96.79000091552734,
#   'volume': 72334400,
#   'adjclose': 90.71913146972656,
#   'formatted_date': '2016-01-20'},
#  {'date': 1453386600,
#   'high': 97.87999725341797,
#   'low': 94.94000244140625,
#   'open': 97.05999755859375,
#   'close': 96.30000305175781,
#   'volume': 52161500,
#   'adjclose': 90.25987243652344,
#   'formatted_date': '2016-01-21'},
#  {'date': 1453473000,
#   'high': 101.45999908447266,
#   'low': 98.37000274658203,
#   'open': 98.62999725341797,
#   'close': 101.41999816894531,
#   'volume': 65800500,
#   'adjclose': 95.0587387084961,
#   'formatted_date': '2016-01-22'},
#  {'date': 1453732200,
#   'high': 101.52999877929688,
#   'low': 99.20999908447266,
#   'open': 101.5199966430664,
#   'close': 99.44000244140625,
#   'volume': 51794500,
#   'adjclose': 93.20293426513672,
#   'formatted_date': '2016-01-25'},
#  {'date': 1453818600,
#   'high': 100.87999725341797,
#   'low': 98.06999969482422,
#   'open': 99.93000030517578,
#   'close': 99.98999786376953,
#   'volume': 75077000,
#   'adjclose': 93.71843719482422,
#   'formatted_date': '2016-01-26'},
#  {'date': 1453905000,
#   'high': 96.62999725341797,
#   'low': 93.33999633789062,
#   'open': 96.04000091552734,
#   'close': 93.41999816894531,
#   'volume': 133369700,
#   'adjclose': 87.56050872802734,
#   'formatted_date': '2016-01-27'},
#  {'date': 1453991400,
#   'high': 94.5199966430664,
#   'low': 92.38999938964844,
#   'open': 93.79000091552734,
#   'close': 94.08999633789062,
#   'volume': 55678800,
#   'adjclose': 88.18848419189453,
#   'formatted_date': '2016-01-28'},
#  {'date': 1454077800,
#   'high': 97.33999633789062,
#   'low': 94.3499984741211,
#   'open': 94.79000091552734,
#   'close': 97.33999633789062,
#   'volume': 64416500,
#   'adjclose': 91.23464965820312,
#   'formatted_date': '2016-01-29'},
#  {'date': 1454337000,
#   'high': 96.70999908447266,
#   'low': 95.4000015258789,
#   'open': 96.47000122070312,
#   'close': 96.43000030517578,
#   'volume': 40943500,
#   'adjclose': 90.38172149658203,
#   'formatted_date': '2016-02-01'},
#  {'date': 1454423400,
#   'high': 96.04000091552734,
#   'low': 94.27999877929688,
#   'open': 95.41999816894531,
#   'close': 94.4800033569336,
#   'volume': 37357200,
#   'adjclose': 88.55402374267578,
#   'formatted_date': '2016-02-02'},
#  {'date': 1454509800,
#   'high': 96.83999633789062,
#   'low': 94.08000183105469,
#   'open': 95.0,
#   'close': 96.3499984741211,
#   'volume': 45964300,
#   'adjclose': 90.30672454833984,
#   'formatted_date': '2016-02-03'},
#  {'date': 1454596200,
#   'high': 97.33000183105469,
#   'low': 95.19000244140625,
#   'open': 95.86000061035156,
#   'close': 96.5999984741211,
#   'volume': 46471700,
#   'adjclose': 91.03235626220703,
#   'formatted_date': '2016-02-04'},
#  {'date': 1454682600,
#   'high': 96.91999816894531,
#   'low': 93.69000244140625,
#   'open': 96.5199966430664,
#   'close': 94.0199966430664,
#   'volume': 46418100,
#   'adjclose': 88.60105895996094,
#   'formatted_date': '2016-02-05'},
#  {'date': 1454941800,
#   'high': 95.69999694824219,
#   'low': 93.04000091552734,
#   'open': 93.12999725341797,
#   'close': 95.01000213623047,
#   'volume': 54021400,
#   'adjclose': 89.53398895263672,
#   'formatted_date': '2016-02-08'},
#  {'date': 1455028200,
#   'high': 95.94000244140625,
#   'low': 93.93000030517578,
#   'open': 94.29000091552734,
#   'close': 94.98999786376953,
#   'volume': 44331200,
#   'adjclose': 89.51514434814453,
#   'formatted_date': '2016-02-09'},
#  {'date': 1455114600,
#   'high': 96.3499984741211,
#   'low': 94.0999984741211,
#   'open': 95.91999816894531,
#   'close': 94.2699966430664,
#   'volume': 42343600,
#   'adjclose': 88.83665466308594,
#   'formatted_date': '2016-02-10'},
#  {'date': 1455201000,
#   'high': 94.72000122070312,
#   'low': 92.58999633789062,
#   'open': 93.79000091552734,
#   'close': 93.69999694824219,
#   'volume': 50074700,
#   'adjclose': 88.29949188232422,
#   'formatted_date': '2016-02-11'},
#  {'date': 1455287400,
#   'high': 94.5,
#   'low': 93.01000213623047,
#   'open': 94.19000244140625,
#   'close': 93.98999786376953,
#   'volume': 40351400,
#   'adjclose': 88.57278442382812,
#   'formatted_date': '2016-02-12'},
#  {'date': 1455633000,
#   'high': 96.8499984741211,
#   'low': 94.61000061035156,
#   'open': 95.0199966430664,
#   'close': 96.63999938964844,
#   'volume': 49057900,
#   'adjclose': 91.0700454711914,
#   'formatted_date': '2016-02-16'},
#  {'date': 1455719400,
#   'high': 98.20999908447266,
#   'low': 96.1500015258789,
#   'open': 96.66999816894531,
#   'close': 98.12000274658203,
#   'volume': 44863200,
#   'adjclose': 92.46475219726562,
#   'formatted_date': '2016-02-17'},
#  {'date': 1455805800,
#   'high': 98.88999938964844,
#   'low': 96.08999633789062,
#   'open': 98.83999633789062,
#   'close': 96.26000213623047,
#   'volume': 39021000,
#   'adjclose': 90.71195983886719,
#   'formatted_date': '2016-02-18'},
#  {'date': 1455892200,
#   'high': 96.76000213623047,
#   'low': 95.80000305175781,
#   'open': 96.0,
#   'close': 96.04000091552734,
#   'volume': 35374200,
#   'adjclose': 90.504638671875,
#   'formatted_date': '2016-02-19'},
#  {'date': 1456151400,
#   'high': 96.9000015258789,
#   'low': 95.91999816894531,
#   'open': 96.30999755859375,
#   'close': 96.87999725341797,
#   'volume': 34280800,
#   'adjclose': 91.29621887207031,
#   'formatted_date': '2016-02-22'},
#  {'date': 1456237800,
#   'high': 96.5,
#   'low': 94.55000305175781,
#   'open': 96.4000015258789,
#   'close': 94.69000244140625,
#   'volume': 31942600,
#   'adjclose': 89.23242950439453,
#   'formatted_date': '2016-02-23'},
#  {'date': 1456324200,
#   'high': 96.37999725341797,
#   'low': 93.31999969482422,
#   'open': 93.9800033569336,
#   'close': 96.0999984741211,
#   'volume': 36255700,
#   'adjclose': 90.56116485595703,
#   'formatted_date': '2016-02-24'},
#  {'date': 1456410600,
#   'high': 96.76000213623047,
#   'low': 95.25,
#   'open': 96.05000305175781,
#   'close': 96.76000213623047,
#   'volume': 27582700,
#   'adjclose': 91.18312072753906,
#   'formatted_date': '2016-02-25'},
#  {'date': 1456497000,
#   'high': 98.0199966430664,
#   'low': 96.58000183105469,
#   'open': 97.19999694824219,
#   'close': 96.91000366210938,
#   'volume': 28991100,
#   'adjclose': 91.32449340820312,
#   'formatted_date': '2016-02-26'},
#  {'date': 1456756200,
#   'high': 98.2300033569336,
#   'low': 96.6500015258789,
#   'open': 96.86000061035156,
#   'close': 96.69000244140625,
#   'volume': 35216300,
#   'adjclose': 91.11715698242188,
#   'formatted_date': '2016-02-29'},
#  {'date': 1456842600,
#   'high': 100.7699966430664,
#   'low': 97.41999816894531,
#   'open': 97.6500015258789,
#   'close': 100.52999877929688,
#   'volume': 50407100,
#   'adjclose': 94.73583984375,
#   'formatted_date': '2016-03-01'},
#  {'date': 1456929000,
#   'high': 100.88999938964844,
#   'low': 99.63999938964844,
#   'open': 100.51000213623047,
#   'close': 100.75,
#   'volume': 33169600,
#   'adjclose': 94.94316101074219,
#   'formatted_date': '2016-03-02'},
#  {'date': 1457015400,
#   'high': 101.70999908447266,
#   'low': 100.44999694824219,
#   'open': 100.58000183105469,
#   'close': 101.5,
#   'volume': 36955700,
#   'adjclose': 95.64993286132812,
#   'formatted_date': '2016-03-03'},
#  {'date': 1457101800,
#   'high': 103.75,
#   'low': 101.37000274658203,
#   'open': 102.37000274658203,
#   'close': 103.01000213623047,
#   'volume': 46055100,
#   'adjclose': 97.07290649414062,
#   'formatted_date': '2016-03-04'},
#  {'date': 1457361000,
#   'high': 102.83000183105469,
#   'low': 100.95999908447266,
#   'open': 102.38999938964844,
#   'close': 101.87000274658203,
#   'volume': 35828900,
#   'adjclose': 95.99861907958984,
#   'formatted_date': '2016-03-07'},
#  {'date': 1457447400,
#   'high': 101.76000213623047,
#   'low': 100.4000015258789,
#   'open': 100.77999877929688,
#   'close': 101.02999877929688,
#   'volume': 31561900,
#   'adjclose': 95.20703125,
#   'formatted_date': '2016-03-08'},
#  {'date': 1457533800,
#   'high': 101.58000183105469,
#   'low': 100.2699966430664,
#   'open': 101.30999755859375,
#   'close': 101.12000274658203,
#   'volume': 27201700,
#   'adjclose': 95.29185485839844,
#   'formatted_date': '2016-03-09'},
#  {'date': 1457620200,
#   'high': 102.23999786376953,
#   'low': 100.1500015258789,
#   'open': 101.41000366210938,
#   'close': 101.16999816894531,
#   'volume': 33513600,
#   'adjclose': 95.33894348144531,
#   'formatted_date': '2016-03-10'},
#  {'date': 1457706600,
#   'high': 102.27999877929688,
#   'low': 101.5,
#   'open': 102.23999786376953,
#   'close': 102.26000213623047,
#   'volume': 27408200,
#   'adjclose': 96.36614227294922,
#   'formatted_date': '2016-03-11'},
#  {'date': 1457962200,
#   'high': 102.91000366210938,
#   'low': 101.77999877929688,
#   'open': 101.91000366210938,
#   'close': 102.5199966430664,
#   'volume': 25076100,
#   'adjclose': 96.61114501953125,
#   'formatted_date': '2016-03-14'},
#  {'date': 1458048600,
#   'high': 105.18000030517578,
#   'low': 103.8499984741211,
#   'open': 103.95999908447266,
#   'close': 104.58000183105469,
#   'volume': 40067700,
#   'adjclose': 98.55241394042969,
#   'formatted_date': '2016-03-15'},
#  {'date': 1458135000,
#   'high': 106.30999755859375,
#   'low': 104.58999633789062,
#   'open': 104.61000061035156,
#   'close': 105.97000122070312,
#   'volume': 38303500,
#   'adjclose': 99.8623046875,
#   'formatted_date': '2016-03-16'},
#  {'date': 1458221400,
#   'high': 106.47000122070312,
#   'low': 104.95999908447266,
#   'open': 105.5199966430664,
#   'close': 105.80000305175781,
#   'volume': 34420700,
#   'adjclose': 99.70211029052734,
#   'formatted_date': '2016-03-17'},
#  {'date': 1458307800,
#   'high': 106.5,
#   'low': 105.19000244140625,
#   'open': 106.33999633789062,
#   'close': 105.91999816894531,
#   'volume': 44205200,
#   'adjclose': 99.81517791748047,
#   'formatted_date': '2016-03-18'},
#  {'date': 1458567000,
#   'high': 107.6500015258789,
#   'low': 105.13999938964844,
#   'open': 105.93000030517578,
#   'close': 105.91000366210938,
#   'volume': 35502700,
#   'adjclose': 99.8057632446289,
#   'formatted_date': '2016-03-21'},
#  {'date': 1458653400,
#   'high': 107.29000091552734,
#   'low': 105.20999908447266,
#   'open': 105.25,
#   'close': 106.72000122070312,
#   'volume': 32444400,
#   'adjclose': 100.56906127929688,
#   'formatted_date': '2016-03-22'},
#  {'date': 1458739800,
#   'high': 107.06999969482422,
#   'low': 105.9000015258789,
#   'open': 106.4800033569336,
#   'close': 106.12999725341797,
#   'volume': 25703500,
#   'adjclose': 100.01307678222656,
#   'formatted_date': '2016-03-23'},
#  {'date': 1458826200,
#   'high': 106.25,
#   'low': 104.88999938964844,
#   'open': 105.47000122070312,
#   'close': 105.66999816894531,
#   'volume': 26133000,
#   'adjclose': 99.57960510253906,
#   'formatted_date': '2016-03-24'},
#  {'date': 1459171800,
#   'high': 106.19000244140625,
#   'low': 105.05999755859375,
#   'open': 106.0,
#   'close': 105.19000244140625,
#   'volume': 19411400,
#   'adjclose': 99.12726593017578,
#   'formatted_date': '2016-03-28'},
#  {'date': 1459258200,
#   'high': 107.79000091552734,
#   'low': 104.87999725341797,
#   'open': 104.88999938964844,
#   'close': 107.68000030517578,
#   'volume': 31190100,
#   'adjclose': 101.47373962402344,
#   'formatted_date': '2016-03-29'},
#  {'date': 1459344600,
#   'high': 110.41999816894531,
#   'low': 108.5999984741211,
#   'open': 108.6500015258789,
#   'close': 109.55999755859375,
#   'volume': 45601100,
#   'adjclose': 103.2453842163086,
#   'formatted_date': '2016-03-30'},
#  {'date': 1459431000,
#   'high': 109.9000015258789,
#   'low': 108.87999725341797,
#   'open': 109.72000122070312,
#   'close': 108.98999786376953,
#   'volume': 25888400,
#   'adjclose': 102.70824432373047,
#   'formatted_date': '2016-03-31'},
#  {'date': 1459517400,
#   'high': 110.0,
#   'low': 108.19999694824219,
#   'open': 108.77999877929688,
#   'close': 109.98999786376953,
#   'volume': 25874000,
#   'adjclose': 103.65060424804688,
#   'formatted_date': '2016-04-01'},
#  {'date': 1459776600,
#   'high': 112.19000244140625,
#   'low': 110.2699966430664,
#   'open': 110.41999816894531,
#   'close': 111.12000274658203,
#   'volume': 37356200,
#   'adjclose': 104.7154769897461,
#   'formatted_date': '2016-04-04'},
#  {'date': 1459863000,
#   'high': 110.7300033569336,
#   'low': 109.41999816894531,
#   'open': 109.51000213623047,
#   'close': 109.80999755859375,
#   'volume': 26578700,
#   'adjclose': 103.48098754882812,
#   'formatted_date': '2016-04-05'},
#  {'date': 1459949400,
#   'high': 110.9800033569336,
#   'low': 109.19999694824219,
#   'open': 110.2300033569336,
#   'close': 110.95999908447266,
#   'volume': 26404100,
#   'adjclose': 104.56468200683594,
#   'formatted_date': '2016-04-06'},
#  {'date': 1460035800,
#   'high': 110.41999816894531,
#   'low': 108.12000274658203,
#   'open': 109.94999694824219,
#   'close': 108.54000091552734,
#   'volume': 31801900,
#   'adjclose': 102.28417205810547,
#   'formatted_date': '2016-04-07'},
#  {'date': 1460122200,
#   'high': 109.7699966430664,
#   'low': 108.16999816894531,
#   'open': 108.91000366210938,
#   'close': 108.66000366210938,
#   'volume': 23581700,
#   'adjclose': 102.39727020263672,
#   'formatted_date': '2016-04-08'},
#  {'date': 1460381400,
#   'high': 110.61000061035156,
#   'low': 108.83000183105469,
#   'open': 108.97000122070312,
#   'close': 109.0199966430664,
#   'volume': 29407500,
#   'adjclose': 102.73651885986328,
#   'formatted_date': '2016-04-11'},
#  {'date': 1460467800,
#   'high': 110.5,
#   'low': 108.66000366210938,
#   'open': 109.33999633789062,
#   'close': 110.44000244140625,
#   'volume': 27232300,
#   'adjclose': 104.0746841430664,
#   'formatted_date': '2016-04-12'},
#  {'date': 1460554200,
#   'high': 112.33999633789062,
#   'low': 110.80000305175781,
#   'open': 110.80000305175781,
#   'close': 112.04000091552734,
#   'volume': 33257300,
#   'adjclose': 105.58246612548828,
#   'formatted_date': '2016-04-13'},
#  {'date': 1460640600,
#   'high': 112.38999938964844,
#   'low': 111.33000183105469,
#   'open': 111.62000274658203,
#   'close': 112.0999984741211,
#   'volume': 25473900,
#   'adjclose': 105.63898468017578,
#   'formatted_date': '2016-04-14'},
#  {'date': 1460727000,
#   'high': 112.30000305175781,
#   'low': 109.7300033569336,
#   'open': 112.11000061035156,
#   'close': 109.8499984741211,
#   'volume': 46939000,
#   'adjclose': 103.51866912841797,
#   'formatted_date': '2016-04-15'},
#  {'date': 1460986200,
#   'high': 108.94999694824219,
#   'low': 106.94000244140625,
#   'open': 108.88999938964844,
#   'close': 107.4800033569336,
#   'volume': 60821500,
#   'adjclose': 101.28527069091797,
#   'formatted_date': '2016-04-18'},
#  {'date': 1461072600,
#   'high': 108.0,
#   'low': 106.2300033569336,
#   'open': 107.87999725341797,
#   'close': 106.91000366210938,
#   'volume': 32384900,
#   'adjclose': 100.74813079833984,
#   'formatted_date': '2016-04-19'},
#  {'date': 1461159000,
#   'high': 108.08999633789062,
#   'low': 106.05999755859375,
#   'open': 106.63999938964844,
#   'close': 107.12999725341797,
#   'volume': 30611000,
#   'adjclose': 100.95545196533203,
#   'formatted_date': '2016-04-20'},
#  {'date': 1461245400,
#   'high': 106.93000030517578,
#   'low': 105.5199966430664,
#   'open': 106.93000030517578,
#   'close': 105.97000122070312,
#   'volume': 31552500,
#   'adjclose': 99.8623046875,
#   'formatted_date': '2016-04-21'},
#  {'date': 1461331800,
#   'high': 106.4800033569336,
#   'low': 104.62000274658203,
#   'open': 105.01000213623047,
#   'close': 105.68000030517578,
#   'volume': 33683100,
#   'adjclose': 99.58902740478516,
#   'formatted_date': '2016-04-22'},
#  {'date': 1461591000,
#   'high': 105.6500015258789,
#   'low': 104.51000213623047,
#   'open': 105.0,
#   'close': 105.08000183105469,
#   'volume': 28031600,
#   'adjclose': 99.02359771728516,
#   'formatted_date': '2016-04-25'},
#  {'date': 1461677400,
#   'high': 105.30000305175781,
#   'low': 103.91000366210938,
#   'open': 103.91000366210938,
#   'close': 104.3499984741211,
#   'volume': 56016200,
#   'adjclose': 98.33567810058594,
#   'formatted_date': '2016-04-26'},
#  {'date': 1461763800,
#   'high': 98.70999908447266,
#   'low': 95.68000030517578,
#   'open': 96.0,
#   'close': 97.81999969482422,
#   'volume': 114602100,
#   'adjclose': 92.18204498291016,
#   'formatted_date': '2016-04-27'},
#  {'date': 1461850200,
#   'high': 97.87999725341797,
#   'low': 94.25,
#   'open': 97.61000061035156,
#   'close': 94.83000183105469,
#   'volume': 82242700,
#   'adjclose': 89.36436462402344,
#   'formatted_date': '2016-04-28'},
#  {'date': 1461936600,
#   'high': 94.72000122070312,
#   'low': 92.51000213623047,
#   'open': 93.98999786376953,
#   'close': 93.73999786376953,
#   'volume': 68531500,
#   'adjclose': 88.33718872070312,
#   'formatted_date': '2016-04-29'},
#  {'date': 1462195800,
#   'high': 94.08000183105469,
#   'low': 92.4000015258789,
#   'open': 93.97000122070312,
#   'close': 93.63999938964844,
#   'volume': 48160100,
#   'adjclose': 88.24295043945312,
#   'formatted_date': '2016-05-02'},
#  {'date': 1462282200,
#   'high': 95.73999786376953,
#   'low': 93.68000030517578,
#   'open': 94.19999694824219,
#   'close': 95.18000030517578,
#   'volume': 56831300,
#   'adjclose': 89.6941909790039,
#   'formatted_date': '2016-05-03'},
#  {'date': 1462368600,
#   'high': 95.9000015258789,
#   'low': 93.81999969482422,
#   'open': 95.19999694824219,
#   'close': 94.19000244140625,
#   'volume': 41025500,
#   'adjclose': 88.7612533569336,
#   'formatted_date': '2016-05-04'},
#  {'date': 1462455000,
#   'high': 94.06999969482422,
#   'low': 92.68000030517578,
#   'open': 94.0,
#   'close': 93.23999786376953,
#   'volume': 35890500,
#   'adjclose': 88.4009780883789,
#   'formatted_date': '2016-05-05'},
#  {'date': 1462541400,
#   'high': 93.44999694824219,
#   'low': 91.8499984741211,
#   'open': 93.37000274658203,
#   'close': 92.72000122070312,
#   'volume': 43699900,
#   'adjclose': 87.907958984375,
#   'formatted_date': '2016-05-06'},
#  {'date': 1462800600,
#   'high': 93.7699966430664,
#   'low': 92.58999633789062,
#   'open': 93.0,
#   'close': 92.79000091552734,
#   'volume': 32936400,
#   'adjclose': 87.9743423461914,
#   'formatted_date': '2016-05-09'},
#  {'date': 1462887000,
#   'high': 93.56999969482422,
#   'low': 92.11000061035156,
#   'open': 93.33000183105469,
#   'close': 93.41999816894531,
#   'volume': 33686800,
#   'adjclose': 88.5716323852539,
#   'formatted_date': '2016-05-10'},
#  {'date': 1462973400,
#   'high': 93.56999969482422,
#   'low': 92.45999908447266,
#   'open': 93.4800033569336,
#   'close': 92.51000213623047,
#   'volume': 28719100,
#   'adjclose': 87.70886993408203,
#   'formatted_date': '2016-05-11'},
#  {'date': 1463059800,
#   'high': 92.77999877929688,
#   'low': 89.47000122070312,
#   'open': 92.72000122070312,
#   'close': 90.33999633789062,
#   'volume': 76314700,
#   'adjclose': 85.65148162841797,
#   'formatted_date': '2016-05-12'},
#  {'date': 1463146200,
#   'high': 91.66999816894531,
#   'low': 90.0,
#   'open': 90.0,
#   'close': 90.5199966430664,
#   'volume': 44392800,
#   'adjclose': 85.82213592529297,
#   'formatted_date': '2016-05-13'},
#  {'date': 1463405400,
#   'high': 94.38999938964844,
#   'low': 91.6500015258789,
#   'open': 92.38999938964844,
#   'close': 93.87999725341797,
#   'volume': 61259800,
#   'adjclose': 89.00775909423828,
#   'formatted_date': '2016-05-16'},
#  {'date': 1463491800,
#   'high': 94.69999694824219,
#   'low': 93.01000213623047,
#   'open': 94.55000305175781,
#   'close': 93.48999786376953,
#   'volume': 46916900,
#   'adjclose': 88.63799285888672,
#   'formatted_date': '2016-05-17'},
#  {'date': 1463578200,
#   'high': 95.20999908447266,
#   'low': 93.88999938964844,
#   'open': 94.16000366210938,
#   'close': 94.55999755859375,
#   'volume': 42062400,
#   'adjclose': 89.6524658203125,
#   'formatted_date': '2016-05-18'},
#  {'date': 1463664600,
#   'high': 94.63999938964844,
#   'low': 93.56999969482422,
#   'open': 94.63999938964844,
#   'close': 94.19999694824219,
#   'volume': 30442100,
#   'adjclose': 89.3111572265625,
#   'formatted_date': '2016-05-19'},
#  {'date': 1463751000,
#   'high': 95.43000030517578,
#   'low': 94.5199966430664,
#   'open': 94.63999938964844,
#   'close': 95.22000122070312,
#   'volume': 32026000,
#   'adjclose': 90.27822875976562,
#   'formatted_date': '2016-05-20'},
#  {'date': 1464010200,
#   'high': 97.19000244140625,
#   'low': 95.66999816894531,
#   'open': 95.87000274658203,
#   'close': 96.43000030517578,
#   'volume': 38018600,
#   'adjclose': 91.42542266845703,
#   'formatted_date': '2016-05-23'},
#  {'date': 1464096600,
#   'high': 98.08999633789062,
#   'low': 96.83999633789062,
#   'open': 97.22000122070312,
#   'close': 97.9000015258789,
#   'volume': 35140200,
#   'adjclose': 92.81913757324219,
#   'formatted_date': '2016-05-24'},
#  {'date': 1464183000,
#   'high': 99.73999786376953,
#   'low': 98.11000061035156,
#   'open': 98.66999816894531,
#   'close': 99.62000274658203,
#   'volume': 38168800,
#   'adjclose': 94.44985961914062,
#   'formatted_date': '2016-05-25'},
#  {'date': 1464269400,
#   'high': 100.7300033569336,
#   'low': 98.63999938964844,
#   'open': 99.68000030517578,
#   'close': 100.41000366210938,
#   'volume': 56331200,
#   'adjclose': 95.19886779785156,
#   'formatted_date': '2016-05-26'},
#  {'date': 1464355800,
#   'high': 100.47000122070312,
#   'low': 99.25,
#   'open': 99.44000244140625,
#   'close': 100.3499984741211,
#   'volume': 36341200,
#   'adjclose': 95.14198303222656,
#   'formatted_date': '2016-05-27'},
#  {'date': 1464701400,
#   'high': 100.4000015258789,
#   'low': 98.81999969482422,
#   'open': 99.5999984741211,
#   'close': 99.86000061035156,
#   'volume': 42307200,
#   'adjclose': 94.67741394042969,
#   'formatted_date': '2016-05-31'},
#  {'date': 1464787800,
#   'high': 99.54000091552734,
#   'low': 98.33000183105469,
#   'open': 99.0199966430664,
#   'close': 98.45999908447266,
#   'volume': 29173300,
#   'adjclose': 93.35006713867188,
#   'formatted_date': '2016-06-01'},
#  {'date': 1464874200,
#   'high': 97.83999633789062,
#   'low': 96.62999725341797,
#   'open': 97.5999984741211,
#   'close': 97.72000122070312,
#   'volume': 40191600,
#   'adjclose': 92.64846801757812,
#   'formatted_date': '2016-06-02'},
#  {'date': 1464960600,
#   'high': 98.2699966430664,
#   'low': 97.44999694824219,
#   'open': 97.79000091552734,
#   'close': 97.91999816894531,
#   'volume': 28504900,
#   'adjclose': 92.83809661865234,
#   'formatted_date': '2016-06-03'},
#  {'date': 1465219800,
#   'high': 101.88999938964844,
#   'low': 97.55000305175781,
#   'open': 97.98999786376953,
#   'close': 98.62999725341797,
#   'volume': 23292500,
#   'adjclose': 93.51124572753906,
#   'formatted_date': '2016-06-06'},
#  {'date': 1465306200,
#   'high': 99.87000274658203,
#   'low': 98.95999908447266,
#   'open': 99.25,
#   'close': 99.02999877929688,
#   'volume': 22409500,
#   'adjclose': 93.89048767089844,
#   'formatted_date': '2016-06-07'},
#  {'date': 1465392600,
#   'high': 99.55999755859375,
#   'low': 98.68000030517578,
#   'open': 99.0199966430664,
#   'close': 98.94000244140625,
#   'volume': 20848100,
#   'adjclose': 93.80516052246094,
#   'formatted_date': '2016-06-08'},
#  {'date': 1465479000,
#   'high': 99.98999786376953,
#   'low': 98.45999908447266,
#   'open': 98.5,
#   'close': 99.6500015258789,
#   'volume': 26601400,
#   'adjclose': 94.47831726074219,
#   'formatted_date': '2016-06-09'},
#  {'date': 1465565400,
#   'high': 99.3499984741211,
#   'low': 98.4800033569336,
#   'open': 98.52999877929688,
#   'close': 98.83000183105469,
#   'volume': 31712900,
#   'adjclose': 93.70087432861328,
#   'formatted_date': '2016-06-10'},
#  {'date': 1465824600,
#   'high': 99.12000274658203,
#   'low': 97.0999984741211,
#   'open': 98.69000244140625,
#   'close': 97.33999633789062,
#   'volume': 38020500,
#   'adjclose': 92.28819274902344,
#   'formatted_date': '2016-06-13'},
#  {'date': 1465911000,
#   'high': 98.4800033569336,
#   'low': 96.75,
#   'open': 97.31999969482422,
#   'close': 97.45999908447266,
#   'volume': 31931900,
#   'adjclose': 92.4019546508789,
#   'formatted_date': '2016-06-14'},
#  {'date': 1465997400,
#   'high': 98.41000366210938,
#   'low': 97.02999877929688,
#   'open': 97.81999969482422,
#   'close': 97.13999938964844,
#   'volume': 29445200,
#   'adjclose': 92.09856414794922,
#   'formatted_date': '2016-06-15'},
#  {'date': 1466083800,
#   'high': 97.75,
#   'low': 96.06999969482422,
#   'open': 96.44999694824219,
#   'close': 97.55000305175781,
#   'volume': 31326800,
#   'adjclose': 92.4873046875,
#   'formatted_date': '2016-06-16'},
#  {'date': 1466170200,
#   'high': 96.6500015258789,
#   'low': 95.30000305175781,
#   'open': 96.62000274658203,
#   'close': 95.33000183105469,
#   'volume': 61008200,
#   'adjclose': 90.38251495361328,
#   'formatted_date': '2016-06-17'},
#  {'date': 1466429400,
#   'high': 96.56999969482422,
#   'low': 95.02999877929688,
#   'open': 96.0,
#   'close': 95.0999984741211,
#   'volume': 34411900,
#   'adjclose': 90.16444396972656,
#   'formatted_date': '2016-06-20'},
#  {'date': 1466515800,
#   'high': 96.3499984741211,
#   'low': 94.68000030517578,
#   'open': 94.94000244140625,
#   'close': 95.91000366210938,
#   'volume': 35546400,
#   'adjclose': 90.93241882324219,
#   'formatted_date': '2016-06-21'},
#  {'date': 1466602200,
#   'high': 96.88999938964844,
#   'low': 95.3499984741211,
#   'open': 96.25,
#   'close': 95.55000305175781,
#   'volume': 29219100,
#   'adjclose': 90.59107971191406,
#   'formatted_date': '2016-06-22'},
#  {'date': 1466688600,
#   'high': 96.29000091552734,
#   'low': 95.25,
#   'open': 95.94000244140625,
#   'close': 96.0999984741211,
#   'volume': 32240200,
#   'adjclose': 91.112548828125,
#   'formatted_date': '2016-06-23'},
#  {'date': 1466775000,
#   'high': 94.66000366210938,
#   'low': 92.6500015258789,
#   'open': 92.91000366210938,
#   'close': 93.4000015258789,
#   'volume': 75311400,
#   'adjclose': 88.55268859863281,
#   'formatted_date': '2016-06-24'},
#  {'date': 1467034200,
#   'high': 93.05000305175781,
#   'low': 91.5,
#   'open': 93.0,
#   'close': 92.04000091552734,
#   'volume': 45489600,
#   'adjclose': 87.26325988769531,
#   'formatted_date': '2016-06-27'},
#  {'date': 1467120600,
#   'high': 93.66000366210938,
#   'low': 92.13999938964844,
#   'open': 92.9000015258789,
#   'close': 93.58999633789062,
#   'volume': 40444900,
#   'adjclose': 88.7328109741211,
#   'formatted_date': '2016-06-28'},
#  {'date': 1467207000,
#   'high': 94.55000305175781,
#   'low': 93.62999725341797,
#   'open': 93.97000122070312,
#   'close': 94.4000015258789,
#   'volume': 36531000,
#   'adjclose': 89.50077056884766,
#   'formatted_date': '2016-06-29'},
#  {'date': 1467293400,
#   'high': 95.7699966430664,
#   'low': 94.30000305175781,
#   'open': 94.44000244140625,
#   'close': 95.5999984741211,
#   'volume': 35836400,
#   'adjclose': 90.63848876953125,
#   'formatted_date': '2016-06-30'},
#  {'date': 1467379800,
#   'high': 96.47000122070312,
#   'low': 95.33000183105469,
#   'open': 95.48999786376953,
#   'close': 95.88999938964844,
#   'volume': 26026500,
#   'adjclose': 90.91344451904297,
#   'formatted_date': '2016-07-01'},
#  {'date': 1467725400,
#   'high': 95.4000015258789,
#   'low': 94.45999908447266,
#   'open': 95.38999938964844,
#   'close': 94.98999786376953,
#   'volume': 27705200,
#   'adjclose': 90.06015014648438,
#   'formatted_date': '2016-07-05'},
#  {'date': 1467811800,
#   'high': 95.66000366210938,
#   'low': 94.37000274658203,
#   'open': 94.5999984741211,
#   'close': 95.52999877929688,
#   'volume': 30949100,
#   'adjclose': 90.57213592529297,
#   'formatted_date': '2016-07-06'},
#  {'date': 1467898200,
#   'high': 96.5,
#   'low': 95.62000274658203,
#   'open': 95.69999694824219,
#   'close': 95.94000244140625,
#   'volume': 25139600,
#   'adjclose': 90.96085357666016,
#   'formatted_date': '2016-07-07'},
#  {'date': 1467984600,
#   'high': 96.88999938964844,
#   'low': 96.05000305175781,
#   'open': 96.48999786376953,
#   'close': 96.68000030517578,
#   'volume': 28912100,
#   'adjclose': 91.66244506835938,
#   'formatted_date': '2016-07-08'},
#  {'date': 1468243800,
#   'high': 97.6500015258789,
#   'low': 96.7300033569336,
#   'open': 96.75,
#   'close': 96.9800033569336,
#   'volume': 23794900,
#   'adjclose': 91.94688415527344,
#   'formatted_date': '2016-07-11'},
#  {'date': 1468330200,
#   'high': 97.69999694824219,
#   'low': 97.12000274658203,
#   'open': 97.16999816894531,
#   'close': 97.41999816894531,
#   'volume': 24167500,
#   'adjclose': 92.36404418945312,
#   'formatted_date': '2016-07-12'},
#  {'date': 1468416600,
#   'high': 97.66999816894531,
#   'low': 96.83999633789062,
#   'open': 97.41000366210938,
#   'close': 96.87000274658203,
#   'volume': 25892200,
#   'adjclose': 91.84259796142578,
#   'formatted_date': '2016-07-13'},
#  {'date': 1468503000,
#   'high': 98.98999786376953,
#   'low': 97.31999969482422,
#   'open': 97.38999938964844,
#   'close': 98.79000091552734,
#   'volume': 38919000,
#   'adjclose': 93.6629409790039,
#   'formatted_date': '2016-07-14'},
#  {'date': 1468589400,
#   'high': 99.30000305175781,
#   'low': 98.5,
#   'open': 98.91999816894531,
#   'close': 98.77999877929688,
#   'volume': 30137000,
#   'adjclose': 93.65345001220703,
#   'formatted_date': '2016-07-15'},
#  {'date': 1468848600,
#   'high': 100.12999725341797,
#   'low': 98.5999984741211,
#   'open': 98.69999694824219,
#   'close': 99.83000183105469,
#   'volume': 36493900,
#   'adjclose': 94.64896392822266,
#   'formatted_date': '2016-07-18'},
#  {'date': 1468935000,
#   'high': 100.0,
#   'low': 99.33999633789062,
# ...
#  {'date': 1559050200,
#   'high': 180.58999633789062,
#   'low': 177.91000366210938,
#   'open': 178.9199981689453,
#   'close': 178.22999572753906,
#   'volume': 27948200,
#   'adjclose': 177.55538940429688,
#   'formatted_date': '2019-05-28'},
#  {'date': 1559136600,
#   'high': 179.35000610351562,
#   'low': 176.0,
#   'open': 176.4199981689453,
#   'close': 177.3800048828125,
#   'volume': 28481200,
#   'adjclose': 176.70860290527344,
#   'formatted_date': '2019-05-29'},
#  {'date': 1559223000,
#   'high': 179.22999572753906,
#   'low': 176.6699981689453,
#   'open': 177.9499969482422,
#   'close': 178.3000030517578,
#   'volume': 21218400,
#   'adjclose': 177.6251220703125,
#   'formatted_date': '2019-05-30'},
#  {'date': 1559309400,
#   'high': 177.99000549316406,
#   'low': 174.99000549316406,
#   'open': 176.22999572753906,
#   'close': 175.07000732421875,
#   'volume': 27043600,
#   'adjclose': 174.4073486328125,
#   'formatted_date': '2019-05-31'},
#  {'date': 1559568600,
#   'high': 177.9199981689453,
#   'low': 170.27000427246094,
#   'open': 175.60000610351562,
#   'close': 173.3000030517578,
#   'volume': 40396100,
#   'adjclose': 172.64404296875,
#   'formatted_date': '2019-06-03'},
#  {'date': 1559655000,
#   'high': 179.8300018310547,
#   'low': 174.52000427246094,
#   'open': 175.44000244140625,
#   'close': 179.63999938964844,
#   'volume': 30968000,
#   'adjclose': 178.96005249023438,
#   'formatted_date': '2019-06-04'},
#  {'date': 1559741400,
#   'high': 184.99000549316406,
#   'low': 181.13999938964844,
#   'open': 184.27999877929688,
#   'close': 182.5399932861328,
#   'volume': 29773400,
#   'adjclose': 181.84906005859375,
#   'formatted_date': '2019-06-05'},
#  {'date': 1559827800,
#   'high': 185.47000122070312,
#   'low': 182.14999389648438,
#   'open': 183.0800018310547,
#   'close': 185.22000122070312,
#   'volume': 22526300,
#   'adjclose': 184.51893615722656,
#   'formatted_date': '2019-06-06'},
#  {'date': 1559914200,
#   'high': 191.9199981689453,
#   'low': 185.77000427246094,
#   'open': 186.50999450683594,
#   'close': 190.14999389648438,
#   'volume': 30684400,
#   'adjclose': 189.43026733398438,
#   'formatted_date': '2019-06-07'},
#  {'date': 1560173400,
#   'high': 195.3699951171875,
#   'low': 191.6199951171875,
#   'open': 191.80999755859375,
#   'close': 192.5800018310547,
#   'volume': 26220900,
#   'adjclose': 191.85107421875,
#   'formatted_date': '2019-06-10'},
#  {'date': 1560259800,
#   'high': 196.0,
#   'low': 193.60000610351562,
#   'open': 194.86000061035156,
#   'close': 194.80999755859375,
#   'volume': 26932900,
#   'adjclose': 194.0726318359375,
#   'formatted_date': '2019-06-11'},
#  {'date': 1560346200,
#   'high': 195.97000122070312,
#   'low': 193.38999938964844,
#   'open': 193.9499969482422,
#   'close': 194.19000244140625,
#   'volume': 18253200,
#   'adjclose': 193.45498657226562,
#   'formatted_date': '2019-06-12'},
#  {'date': 1560432600,
#   'high': 196.7899932861328,
#   'low': 193.60000610351562,
#   'open': 194.6999969482422,
#   'close': 194.14999389648438,
#   'volume': 21674600,
#   'adjclose': 193.4151153564453,
#   'formatted_date': '2019-06-13'},
#  {'date': 1560519000,
#   'high': 193.58999633789062,
#   'low': 190.3000030517578,
#   'open': 191.5500030517578,
#   'close': 192.74000549316406,
#   'volume': 18761500,
#   'adjclose': 192.01046752929688,
#   'formatted_date': '2019-06-14'},
#  {'date': 1560778200,
#   'high': 194.9600067138672,
#   'low': 192.1699981689453,
#   'open': 192.89999389648438,
#   'close': 193.88999938964844,
#   'volume': 14669100,
#   'adjclose': 193.15611267089844,
#   'formatted_date': '2019-06-17'},
#  {'date': 1560864600,
#   'high': 200.2899932861328,
#   'low': 195.2100067138672,
#   'open': 196.0500030517578,
#   'close': 198.4499969482422,
#   'volume': 26551000,
#   'adjclose': 197.6988525390625,
#   'formatted_date': '2019-06-18'},
#  {'date': 1560951000,
#   'high': 199.8800048828125,
#   'low': 197.30999755859375,
#   'open': 199.67999267578125,
#   'close': 197.8699951171875,
#   'volume': 21124200,
#   'adjclose': 197.1210479736328,
#   'formatted_date': '2019-06-19'},
#  {'date': 1561037400,
#   'high': 200.61000061035156,
#   'low': 198.02999877929688,
#   'open': 200.3699951171875,
#   'close': 199.4600067138672,
#   'volume': 21514000,
#   'adjclose': 198.7050323486328,
#   'formatted_date': '2019-06-20'},
#  {'date': 1561123800,
#   'high': 200.85000610351562,
#   'low': 198.14999389648438,
#   'open': 198.8000030517578,
#   'close': 198.77999877929688,
#   'volume': 47800600,
#   'adjclose': 198.02760314941406,
#   'formatted_date': '2019-06-21'},
#  {'date': 1561383000,
#   'high': 200.16000366210938,
#   'low': 198.1699981689453,
#   'open': 198.5399932861328,
#   'close': 198.5800018310547,
#   'volume': 18220400,
#   'adjclose': 197.828369140625,
#   'formatted_date': '2019-06-24'},
#  {'date': 1561469400,
#   'high': 199.25999450683594,
#   'low': 195.2899932861328,
#   'open': 198.42999267578125,
#   'close': 195.57000732421875,
#   'volume': 21070300,
#   'adjclose': 194.8297576904297,
#   'formatted_date': '2019-06-25'},
#  {'date': 1561555800,
#   'high': 200.99000549316406,
#   'low': 197.35000610351562,
#   'open': 197.77000427246094,
#   'close': 199.8000030517578,
#   'volume': 26067500,
#   'adjclose': 199.0437469482422,
#   'formatted_date': '2019-06-26'},
#  {'date': 1561642200,
#   'high': 201.57000732421875,
#   'low': 199.57000732421875,
#   'open': 200.2899932861328,
#   'close': 199.74000549316406,
#   'volume': 20899700,
#   'adjclose': 198.98397827148438,
#   'formatted_date': '2019-06-27'},
#  {'date': 1561728600,
#   'high': 199.5,
#   'low': 197.0500030517578,
#   'open': 198.67999267578125,
#   'close': 197.9199981689453,
#   'volume': 31110600,
#   'adjclose': 197.1708526611328,
#   'formatted_date': '2019-06-28'},
#  {'date': 1561987800,
#   'high': 204.49000549316406,
#   'low': 200.64999389648438,
#   'open': 203.1699981689453,
#   'close': 201.5500030517578,
#   'volume': 27253000,
#   'adjclose': 200.78712463378906,
#   'formatted_date': '2019-07-01'},
#  {'date': 1562074200,
#   'high': 203.1300048828125,
#   'low': 201.36000061035156,
#   'open': 201.41000366210938,
#   'close': 202.72999572753906,
#   'volume': 16935200,
#   'adjclose': 201.962646484375,
#   'formatted_date': '2019-07-02'},
#  {'date': 1562160600,
#   'high': 204.44000244140625,
#   'low': 202.69000244140625,
#   'open': 203.27999877929688,
#   'close': 204.41000366210938,
#   'volume': 11362000,
#   'adjclose': 203.63629150390625,
#   'formatted_date': '2019-07-03'},
#  {'date': 1562333400,
#   'high': 205.0800018310547,
#   'low': 202.89999389648438,
#   'open': 203.35000610351562,
#   'close': 204.22999572753906,
#   'volume': 17265500,
#   'adjclose': 203.45697021484375,
#   'formatted_date': '2019-07-05'},
#  {'date': 1562592600,
#   'high': 201.39999389648438,
#   'low': 198.41000366210938,
#   'open': 200.80999755859375,
#   'close': 200.02000427246094,
#   'volume': 25338600,
#   'adjclose': 199.26290893554688,
#   'formatted_date': '2019-07-08'},
#  {'date': 1562679000,
#   'high': 201.50999450683594,
#   'low': 198.80999755859375,
#   'open': 199.1999969482422,
#   'close': 201.24000549316406,
#   'volume': 20578000,
#   'adjclose': 200.47830200195312,
#   'formatted_date': '2019-07-09'},
#  {'date': 1562765400,
#   'high': 203.72999572753906,
#   'low': 201.55999755859375,
#   'open': 201.85000610351562,
#   'close': 203.22999572753906,
#   'volume': 17897100,
#   'adjclose': 202.46075439453125,
#   'formatted_date': '2019-07-10'},
#  {'date': 1562851800,
#   'high': 204.38999938964844,
#   'low': 201.7100067138672,
#   'open': 203.30999755859375,
#   'close': 201.75,
#   'volume': 20191800,
#   'adjclose': 200.98635864257812,
#   'formatted_date': '2019-07-11'},
#  {'date': 1562938200,
#   'high': 204.0,
#   'low': 202.1999969482422,
#   'open': 202.4499969482422,
#   'close': 203.3000030517578,
#   'volume': 17595200,
#   'adjclose': 202.53050231933594,
#   'formatted_date': '2019-07-12'},
#  {'date': 1563197400,
#   'high': 205.8699951171875,
#   'low': 204.0,
#   'open': 204.08999633789062,
#   'close': 205.2100067138672,
#   'volume': 16947400,
#   'adjclose': 204.4332733154297,
#   'formatted_date': '2019-07-15'},
#  {'date': 1563283800,
#   'high': 206.11000061035156,
#   'low': 203.5,
#   'open': 204.58999633789062,
#   'close': 204.5,
#   'volume': 16866800,
#   'adjclose': 203.7259521484375,
#   'formatted_date': '2019-07-16'},
#  {'date': 1563370200,
#   'high': 205.08999633789062,
#   'low': 203.27000427246094,
#   'open': 204.0500030517578,
#   'close': 203.35000610351562,
#   'volume': 14107500,
#   'adjclose': 202.58030700683594,
#   'formatted_date': '2019-07-17'},
#  {'date': 1563456600,
#   'high': 205.8800048828125,
#   'low': 203.6999969482422,
#   'open': 204.0,
#   'close': 205.66000366210938,
#   'volume': 18540600,
#   'adjclose': 204.88156127929688,
#   'formatted_date': '2019-07-18'},
#  {'date': 1563543000,
#   'high': 206.5,
#   'low': 202.36000061035156,
#   'open': 205.7899932861328,
#   'close': 202.58999633789062,
#   'volume': 20929300,
#   'adjclose': 201.82318115234375,
#   'formatted_date': '2019-07-19'},
#  {'date': 1563802200,
#   'high': 207.22999572753906,
#   'low': 203.61000061035156,
#   'open': 203.64999389648438,
#   'close': 207.22000122070312,
#   'volume': 22277900,
#   'adjclose': 206.43565368652344,
#   'formatted_date': '2019-07-22'},
#  {'date': 1563888600,
#   'high': 208.91000366210938,
#   'low': 207.2899932861328,
#   'open': 208.4600067138672,
#   'close': 208.83999633789062,
#   'volume': 18355200,
#   'adjclose': 208.0495147705078,
#   'formatted_date': '2019-07-23'},
#  {'date': 1563975000,
#   'high': 209.14999389648438,
#   'low': 207.1699981689453,
#   'open': 207.6699981689453,
#   'close': 208.6699981689453,
#   'volume': 14991600,
#   'adjclose': 207.8801727294922,
#   'formatted_date': '2019-07-24'},
#  {'date': 1564061400,
#   'high': 209.24000549316406,
#   'low': 206.72999572753906,
#   'open': 208.88999938964844,
#   'close': 207.02000427246094,
#   'volume': 13909600,
#   'adjclose': 206.23641967773438,
#   'formatted_date': '2019-07-25'},
#  {'date': 1564147800,
#   'high': 209.72999572753906,
#   'low': 207.13999938964844,
#   'open': 207.47999572753906,
#   'close': 207.74000549316406,
#   'volume': 17618900,
#   'adjclose': 206.9536895751953,
#   'formatted_date': '2019-07-26'},
#  {'date': 1564407000,
#   'high': 210.63999938964844,
#   'low': 208.44000244140625,
#   'open': 208.4600067138672,
#   'close': 209.67999267578125,
#   'volume': 21673400,
#   'adjclose': 208.88633728027344,
#   'formatted_date': '2019-07-29'},
#  {'date': 1564493400,
#   'high': 210.16000366210938,
#   'low': 207.30999755859375,
#   'open': 208.75999450683594,
#   'close': 208.77999877929688,
#   'volume': 33935700,
#   'adjclose': 207.98974609375,
#   'formatted_date': '2019-07-30'},
#  {'date': 1564579800,
#   'high': 221.3699951171875,
#   'low': 211.3000030517578,
#   'open': 216.4199981689453,
#   'close': 213.0399932861328,
#   'volume': 69281400,
#   'adjclose': 212.23362731933594,
#   'formatted_date': '2019-07-31'},
#  {'date': 1564666200,
#   'high': 218.02999877929688,
#   'low': 206.74000549316406,
#   'open': 213.89999389648438,
#   'close': 208.42999267578125,
#   'volume': 54017900,
#   'adjclose': 207.6410675048828,
#   'formatted_date': '2019-08-01'},
#  {'date': 1564752600,
#   'high': 206.42999267578125,
#   'low': 201.6300048828125,
#   'open': 205.52999877929688,
#   'close': 204.02000427246094,
#   'volume': 40862100,
#   'adjclose': 203.24777221679688,
#   'formatted_date': '2019-08-02'},
#  {'date': 1565011800,
#   'high': 198.64999389648438,
#   'low': 192.5800018310547,
#   'open': 197.99000549316406,
#   'close': 193.33999633789062,
#   'volume': 52393000,
#   'adjclose': 192.60818481445312,
#   'formatted_date': '2019-08-05'},
#  {'date': 1565098200,
#   'high': 198.07000732421875,
#   'low': 194.0399932861328,
#   'open': 196.30999755859375,
#   'close': 197.0,
#   'volume': 35824800,
#   'adjclose': 196.25433349609375,
#   'formatted_date': '2019-08-06'},
#  {'date': 1565184600,
#   'high': 199.55999755859375,
#   'low': 193.82000732421875,
#   'open': 195.41000366210938,
#   'close': 199.0399932861328,
#   'volume': 33364400,
#   'adjclose': 198.28660583496094,
#   'formatted_date': '2019-08-07'},
#  {'date': 1565271000,
#   'high': 203.52999877929688,
#   'low': 199.38999938964844,
#   'open': 200.1999969482422,
#   'close': 203.42999267578125,
#   'volume': 27009500,
#   'adjclose': 202.6599884033203,
#   'formatted_date': '2019-08-08'},
#  {'date': 1565357400,
#   'high': 202.75999450683594,
#   'low': 199.2899932861328,
#   'open': 201.3000030517578,
#   'close': 200.99000549316406,
#   'volume': 24619700,
#   'adjclose': 200.99000549316406,
#   'formatted_date': '2019-08-09'},
#  {'date': 1565616600,
#   'high': 202.0500030517578,
#   'low': 199.14999389648438,
#   'open': 199.6199951171875,
#   'close': 200.47999572753906,
#   'volume': 22481900,
#   'adjclose': 200.47999572753906,
#   'formatted_date': '2019-08-12'},
#  {'date': 1565703000,
#   'high': 212.13999938964844,
#   'low': 200.47999572753906,
#   'open': 201.02000427246094,
#   'close': 208.97000122070312,
#   'volume': 47218500,
#   'adjclose': 208.97000122070312,
#   'formatted_date': '2019-08-13'},
#  {'date': 1565789400,
#   'high': 206.44000244140625,
#   'low': 202.58999633789062,
#   'open': 203.16000366210938,
#   'close': 202.75,
#   'volume': 36547400,
#   'adjclose': 202.75,
#   'formatted_date': '2019-08-14'},
#  {'date': 1565875800,
#   'high': 205.13999938964844,
#   'low': 199.6699981689453,
#   'open': 203.4600067138672,
#   'close': 201.74000549316406,
#   'volume': 27227400,
#   'adjclose': 201.74000549316406,
#   'formatted_date': '2019-08-15'},
#  {'date': 1565962200,
#   'high': 207.16000366210938,
#   'low': 203.83999633789062,
#   'open': 204.27999877929688,
#   'close': 206.5,
#   'volume': 27620400,
#   'adjclose': 206.5,
#   'formatted_date': '2019-08-16'},
#  {'date': 1566221400,
#   'high': 212.72999572753906,
#   'low': 210.02999877929688,
#   'open': 210.6199951171875,
#   'close': 210.35000610351562,
#   'volume': 24413600,
#   'adjclose': 210.35000610351562,
#   'formatted_date': '2019-08-19'},
#  {'date': 1566307800,
#   'high': 213.35000610351562,
#   'low': 210.32000732421875,
#   'open': 210.8800048828125,
#   'close': 210.36000061035156,
#   'volume': 26884300,
#   'adjclose': 210.36000061035156,
#   'formatted_date': '2019-08-20'},
#  {'date': 1566394200,
#   'high': 213.64999389648438,
#   'low': 211.60000610351562,
#   'open': 212.99000549316406,
#   'close': 212.63999938964844,
#   'volume': 21535400,
#   'adjclose': 212.63999938964844,
#   'formatted_date': '2019-08-21'},
#  {'date': 1566480600,
#   'high': 214.44000244140625,
#   'low': 210.75,
#   'open': 213.19000244140625,
#   'close': 212.4600067138672,
#   'volume': 22253700,
#   'adjclose': 212.4600067138672,
#   'formatted_date': '2019-08-22'},
#  {'date': 1566567000,
#   'high': 212.0500030517578,
#   'low': 201.0,
#   'open': 209.42999267578125,
#   'close': 202.63999938964844,
#   'volume': 46818000,
#   'adjclose': 202.63999938964844,
#   'formatted_date': '2019-08-23'},
#  {'date': 1566826200,
#   'high': 207.19000244140625,
#   'low': 205.05999755859375,
#   'open': 205.86000061035156,
#   'close': 206.49000549316406,
#   'volume': 26043600,
#   'adjclose': 206.49000549316406,
#   'formatted_date': '2019-08-26'},
#  {'date': 1566912600,
#   'high': 208.5500030517578,
#   'low': 203.52999877929688,
#   'open': 207.86000061035156,
#   'close': 204.16000366210938,
#   'volume': 25873300,
#   'adjclose': 204.16000366210938,
#   'formatted_date': '2019-08-27'},
#  {'date': 1566999000,
#   'high': 205.72000122070312,
#   'low': 203.32000732421875,
#   'open': 204.10000610351562,
#   'close': 205.52999877929688,
#   'volume': 15938800,
#   'adjclose': 205.52999877929688,
#   'formatted_date': '2019-08-28'},
#  {'date': 1567085400,
#   'high': 209.32000732421875,
#   'low': 206.66000366210938,
#   'open': 208.5,
#   'close': 209.00999450683594,
#   'volume': 20990500,
#   'adjclose': 209.00999450683594,
#   'formatted_date': '2019-08-29'},
#  {'date': 1567171800,
#   'high': 210.4499969482422,
#   'low': 207.1999969482422,
#   'open': 210.16000366210938,
#   'close': 208.74000549316406,
#   'volume': 21143400,
#   'adjclose': 208.74000549316406,
#   'formatted_date': '2019-08-30'},
#  {'date': 1567517400,
#   'high': 206.97999572753906,
#   'low': 204.22000122070312,
#   'open': 206.42999267578125,
#   'close': 205.6999969482422,
#   'volume': 20023000,
#   'adjclose': 205.6999969482422,
#   'formatted_date': '2019-09-03'},
#  {'date': 1567603800,
#   'high': 209.47999572753906,
#   'low': 207.32000732421875,
#   'open': 208.38999938964844,
#   'close': 209.19000244140625,
#   'volume': 19188100,
#   'adjclose': 209.19000244140625,
#   'formatted_date': '2019-09-04'},
#  ...]

# %% [markdown]
# ### Create Data Frame from Dictionary

# %%
price_df = pd.DataFrame.from_dict(prices[0])
price_df.head()
# Out:
#      adjclose       close        date formatted_date        high         low  \
# 0  108.522148  116.279999  1442323800     2015-09-15  116.529999  114.419998
# 1  108.643478  116.410004  1442410200     2015-09-16  116.540001  115.440002
# 2  106.319611  113.919998  1442496600     2015-09-17  116.489998  113.720001
# 3  105.880959  113.449997  1442583000     2015-09-18  114.300003  111.870003
# 4  107.523544  115.209999  1442842200     2015-09-21  115.370003  113.660004
#
#          open    volume
# 0  115.930000  43341200
# 1  116.250000  37173500
# 2  115.660004  64112600
# 3  112.209999  74285300
# 4  113.669998  50222000

# %% [markdown]
# ### Change Dates to DateTime

# %%
price_df['date']=pd.to_datetime(price_df['formatted_date']) 
price_df.head()
# Out:
#      adjclose       close       date formatted_date        high         low  \
# 0  108.522148  116.279999 2015-09-15     2015-09-15  116.529999  114.419998
# 1  108.643478  116.410004 2015-09-16     2015-09-16  116.540001  115.440002
# 2  106.319611  113.919998 2015-09-17     2015-09-17  116.489998  113.720001
# 3  105.880959  113.449997 2015-09-18     2015-09-18  114.300003  111.870003
# 4  107.523544  115.209999 2015-09-21     2015-09-21  115.370003  113.660004
#
#          open    volume
# 0  115.930000  43341200
# 1  116.250000  37173500
# 2  115.660004  64112600
# 3  112.209999  74285300
# 4  113.669998  50222000

# %%
price_df = price_df.set_index(price_df['date'])
price_df.head()
# Out:
#               adjclose       close       date formatted_date        high  \
# date
# 2015-09-15  108.522148  116.279999 2015-09-15     2015-09-15  116.529999
# 2015-09-16  108.643478  116.410004 2015-09-16     2015-09-16  116.540001
# 2015-09-17  106.319611  113.919998 2015-09-17     2015-09-17  116.489998
# 2015-09-18  105.880959  113.449997 2015-09-18     2015-09-18  114.300003
# 2015-09-21  107.523544  115.209999 2015-09-21     2015-09-21  115.370003
#
#                    low        open    volume
# date
# 2015-09-15  114.419998  115.930000  43341200
# 2015-09-16  115.440002  116.250000  37173500
# 2015-09-17  113.720001  115.660004  64112600
# 2015-09-18  111.870003  112.209999  74285300
# 2015-09-21  113.660004  113.669998  50222000

# %%
price_df = price_df.drop(['date', 'formatted_date'], axis=1)
price_df.head()
# Out:
#               adjclose       close        high         low        open  \
# date
# 2015-09-15  108.522148  116.279999  116.529999  114.419998  115.930000
# 2015-09-16  108.643478  116.410004  116.540001  115.440002  116.250000
# 2015-09-17  106.319611  113.919998  116.489998  113.720001  115.660004
# 2015-09-18  105.880959  113.449997  114.300003  111.870003  112.209999
# 2015-09-21  107.523544  115.209999  115.370003  113.660004  113.669998
#
#               volume
# date
# 2015-09-15  43341200
# 2015-09-16  37173500
# 2015-09-17  64112600
# 2015-09-18  74285300
# 2015-09-21  50222000

# %%
# %matplotlib inline
price_df.iloc[:,0:4].cumsum().plot(lw=2.0, grid=True)

# %% [markdown]
# ### Visualize Closing Price

# %%
price_df['close'].plot(figsize=(8, 5), grid=True)

# %% [markdown]
# ### Close Vs. Volume Traded

# %%
price_df[['close', 'volume']].plot(subplots=True, style='b',
                              figsize=(8, 5), grid=True);

# %% [markdown]
# ## [Rolling](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html)

# %% [markdown]
# * Provide rolling window calculations
# * **Window:** Size of the moving window. This is the number of observations used for calculating the statistic. Each window will be a fixed size.

# %%
price_df['42d'] = price_df['close'].rolling(window=42).mean()
price_df['252d'] = price_df['close'].rolling(window=252).mean()

# %%
price_df.head()
# Out:
#              adjclose      close       high        low       open     volume  \
# date
# 2008-09-15  17.499147  20.051428  21.098572  20.051428  20.290001  230158600
# 2008-09-16  17.439302  19.982857  20.357143  18.878571  19.122858  299959100
# 2008-09-17  15.936990  18.261429  19.787144  18.261429  19.784286  300113800
# 2008-09-18  16.717442  19.155714  19.347143  17.240000  18.652857  419063400
# 2008-09-19  17.567715  20.129999  20.600000  19.472857  20.371429  357718900
#
#             42d  252d
# date
# 2008-09-15  NaN   NaN
# 2008-09-16  NaN   NaN
# 2008-09-17  NaN   NaN
# 2008-09-18  NaN   NaN
# 2008-09-19  NaN   NaN

# %%
price_df[['close', '42d', '252d']].plot(figsize=(8, 5), grid=True)

# %% [markdown]
# ## Calculate Return

# %% [markdown]
# **Shift** Shift index by desired number of periods with an optional time freq.

# %%
price_df['close'].shift(1).head()
# Out:
# date
# 2015-09-15           NaN
# 2015-09-16    116.279999
# 2015-09-17    116.410004
# 2015-09-18    113.919998
# 2015-09-21    113.449997
# Name: close, dtype: float64

# %%
price_df['close'].head()
# Out:
# date
# 2015-09-15    116.279999
# 2015-09-16    116.410004
# 2015-09-17    113.919998
# 2015-09-18    113.449997
# 2015-09-21    115.209999
# Name: close, dtype: float64

# %%
price_df['return_log'] = np.log(price_df['close'] / price_df['close'].shift(1))
price_df.head()
# Out:
#               adjclose       close        high         low        open  \
# date
# 2015-09-15  108.522148  116.279999  116.529999  114.419998  115.930000
# 2015-09-16  108.643478  116.410004  116.540001  115.440002  116.250000
# 2015-09-17  106.319611  113.919998  116.489998  113.720001  115.660004
# 2015-09-18  105.880959  113.449997  114.300003  111.870003  112.209999
# 2015-09-21  107.523544  115.209999  115.370003  113.660004  113.669998
#
#               volume  42d  252d  return_log
# date
# 2015-09-15  43341200  NaN   NaN         NaN
# 2015-09-16  37173500  NaN   NaN    0.001117
# 2015-09-17  64112600  NaN   NaN   -0.021622
# 2015-09-18  74285300  NaN   NaN   -0.004134
# 2015-09-21  50222000  NaN   NaN    0.015394

# %%
price_df['return'] = price_df['close'] / price_df['close'].shift(1)
price_df.head()
# Out:
#               adjclose       close        high         low        open  \
# date
# 2015-09-15  108.522148  116.279999  116.529999  114.419998  115.930000
# 2015-09-16  108.643478  116.410004  116.540001  115.440002  116.250000
# 2015-09-17  106.319611  113.919998  116.489998  113.720001  115.660004
# 2015-09-18  105.880959  113.449997  114.300003  111.870003  112.209999
# 2015-09-21  107.523544  115.209999  115.370003  113.660004  113.669998
#
#               volume  42d  252d  return_log    return
# date
# 2015-09-15  43341200  NaN   NaN         NaN       NaN
# 2015-09-16  37173500  NaN   NaN    0.001117  1.001118
# 2015-09-17  64112600  NaN   NaN   -0.021622  0.978610
# 2015-09-18  74285300  NaN   NaN   -0.004134  0.995874
# 2015-09-21  50222000  NaN   NaN    0.015394  1.015513

# %% [markdown]
# ### Plot Return

# %% [markdown]
# Logarithmic Return

# %%
price_df[['close', 'return_log']].plot(subplots=True, style='b',
                              figsize=(8, 5), grid=True);

# %% [markdown]
# Return (No transformation)

# %%
price_df[['close', 'return']].plot(subplots=True, style='b',
                              figsize=(8, 5), grid=True);

# %% [markdown]
# ### [Annualized Volatility](https://www.fool.com/knowledge-center/how-to-calculate-annualized-volatility.aspx)

# %%
price_df['mov_vol'] = price_df['return'].rolling(window=252).std() * math.sqrt(252)

# %%
price_df[['close', 'mov_vol', 'return']].plot(subplots=True, style='r',
                                         figsize=(8, 7), grid=True);

# %% [markdown]
# ## CAPM (Capital Asset Pricing Model)

# %% [markdown]
# <img src="media/capm.jpg" width="400">

# %% [markdown]
# **Beta:**
# The beta of a potential investment is a measure of how much risk the investment will add to a portfolio that looks like the market. If a stock is riskier than the market, it will have a beta greater than one. If a stock has a beta of less than one, the formula assumes it will reduce the risk of a portfolio.

# %% [markdown]
# #### 1. Get information of a Market (I'll use S&P 500)

# %%
ticker = 'SPX'
yahoo_financials = YahooFinancials(ticker)
historical_stock_prices = yahoo_financials.get_historical_price_data('2015-09-15', '2019-10-24', 'daily')

# %%
stock = json_normalize(historical_stock_prices)
prices = stock['SPX.prices']
price_sp = pd.DataFrame.from_dict(prices[0])
price_sp['date']=pd.to_datetime(price_sp['formatted_date']) 
price_sp = price_sp.set_index(price_sp['date'])
price_sp = price_sp.drop(['date', 'formatted_date'], axis=1)

# %%
price_sp.head()
# Out:
#             adjclose  close   high    low   open  volume
# date
# 2015-09-15     0.006  0.006  0.006  0.006  0.006       0
# 2015-09-16     0.006  0.006  0.006  0.006  0.006  100000
# 2015-09-17     0.010  0.010  0.010  0.010  0.010     500
# 2015-09-18     0.010  0.010  0.010  0.010  0.010       0
# 2015-09-21     0.005  0.005  0.005  0.005  0.005       0

# %%
stock_close  = price_df[['close']]
stock_close.columns = ['stock_close']
stock_close.head()
# Out:
#             stock_close
# date
# 2015-09-15   116.279999
# 2015-09-16   116.410004
# 2015-09-17   113.919998
# 2015-09-18   113.449997
# 2015-09-21   115.209999

# %%
len(stock_close)
# Out:
# 1035

# %%
price_sp['return'] = price_sp['close'] / price_sp['close'].shift(1)
sp_close  = price_sp[['close']]
sp_close.columns = ['sp_close']
sp_close.head()
# Out:
#             sp_close
# date
# 2015-09-15     0.006
# 2015-09-16     0.006
# 2015-09-17     0.010
# 2015-09-18     0.010
# 2015-09-21     0.005

# %%
len(sp_close)
# Out:
# 599

# %% [markdown]
# #### 2. Combine information with the same dates

# %%
beta_df = sp_close.join(stock_close)
beta_df.head()
# Out:
#             sp_close  stock_close
# date
# 2015-09-15     0.006   116.279999
# 2015-09-16     0.006   116.410004
# 2015-09-17     0.010   113.919998
# 2015-09-18     0.010   113.449997
# 2015-09-21     0.005   115.209999

# %%
len(beta_df)
# Out:
# 599

# %% [markdown]
# #### 3. Normalize (So that we can see better how prices are distributed in a Plot)

# %% [markdown]
# **If we don't**

# %%
qn_a = beta_df['sp_close']
qn_b = beta_df['stock_close']

plt.plot(qn_a,qn_b, ls="", marker="o")

x = np.linspace(np.min((qn_a.min(),qn_b.min())), np.max((qn_a.max(),qn_b.max())))
plt.plot(x,x, color="k", ls="--")

plt.show()

# %%
x = beta_df.values 
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
beta_df_norm = pd.DataFrame(x_scaled)

# %%
beta_df_norm = beta_df_norm.dropna()
beta_df_norm.head()
# Out:
#           0         1
# 0  0.030303  0.291723
# 1  0.030303  0.293185
# 2  0.090909  0.265182
# 3  0.090909  0.259897
# 4  0.015152  0.279690

# %%
qn_a = beta_df_norm[0]
qn_b = beta_df_norm[1]

plt.plot(qn_a,qn_b, ls="", marker="o")

x = np.linspace(np.min((qn_a.min(),qn_b.min())), np.max((qn_a.max(),qn_b.max())))
plt.plot(x,x, color="k", ls="--")

plt.show()

# %% [markdown]
# #### Simple Linear Regression To Understand Our Data

# %%
xdat = qn_a.values
ydat = qn_b.values
reg = np.polyfit(x=xdat, y=ydat, deg=1)
reg
# Out:
# array([0.5332743 , 0.24410859])

# %%
plt.plot(xdat, ydat, 'r.')
ax = plt.axis()  # grab axis values
x = np.linspace(ax[0], ax[1] + 0.01)
plt.plot(x, np.polyval(reg, x), 'b', lw=2)
plt.grid(True)
plt.axis('tight')
plt.xlabel('S&P 500 returns')
plt.ylabel('AAPL returns')
# Out:
# Text(0, 0.5, 'AAPL returns')

# %% [markdown]
# ### Going Back To CAPM Formula

# %% [markdown]
# <img src="media/beta.jpg" width="400">

# %%
correl = beta_df.corr()
correl
# Out:
#              sp_close  stock_close
# sp_close     1.000000     0.497826
# stock_close  0.497826     1.000000

# %%
correl = correl.iloc[1,0]
correl
# Out:
# 0.4978262542544196

# %%
st_sp = beta_df_norm[0].std()
st_sp
# Out:
# 0.26894589635038596

# %%
st_stock = beta_df_norm[1].std()
st_stock
# Out:
# 0.2880963631420668

# %% [markdown]
# ## OUR BETA (Correlation Method)

# %%
beta = correl*(st_stock/st_sp)
beta
# Out:
# 0.5332742952154375

# %% [markdown]
# ## OUR BETA (Covariance/Variance)

# %%
covar = beta_df.cov()
covar
# Out:
#              sp_close  stock_close
# sp_close     0.000315     0.226373
# stock_close  0.226373   656.257745

# %%
covar = covar.iloc[1,0]
covar
# Out:
# 0.2263726088375116

# %%
var_sp = beta_df_norm[0].var()
var_sp
# Out:
# 0.07233189516371255

# %%
beta_2 = covar/var_sp
beta_2
# Out:
# 3.1296374624935606
