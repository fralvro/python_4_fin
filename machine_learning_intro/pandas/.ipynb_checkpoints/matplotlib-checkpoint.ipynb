# %% [markdown]
# # Jumping into Matplotlib and Seaborn
# Francisco Alvarez 03/05

# %% [markdown]
# <img src="jump.gif" width="400">

# %% [markdown]
# # 1. BASICS

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import pandas as pd
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## The Plot

# %% [markdown]
# Creating a single figure

# %%
fig, ax = plt.subplots()

# %% [markdown]
# A very simple plot with x and y sets

# %% [markdown]
# Figure containing a single axes

# %%
fig, ax = plt.subplots()  # Note it is Object Oriented
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.show()

# %% [markdown]
# The previous example can be written in a sipler way like this:

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %% [markdown]
# Performs that plot on the "current" axes, creating that axes (and its parent figure) if they don't exist yet.
# In other words: Uses default stuff to create the plot

# %% [markdown]
# ### Why are there two ways of writing the code for the matplotlib plots??

# %% [markdown]
# Matplotlib has two interfaces.
#
# **1.** The first is an object-oriented (OO)
# interface. In this case, we utilize an instance of:
# * **Axes** in order to render visualizations
# * **Figure** as the base

# %% [markdown]
# **2.** The second is based on MATLAB and uses a state-based interface. This is
# encapsulated in the **pyplot** module.

# %% [markdown]
# ### Note
#
# We call methods that do the plotting directly from the Axes, which gives
# us much more flexibility and power in customizing our plot.
#
# In general, try to use the object-oriented interface over the pyplot interface.

# %% [markdown]
# Most of the terms are straightforward but the main thing to remember
# is that:
# * The Figure is the final image that may contain 1 or more Axes.
# * The Axes represent an individual plot (don't confuse this with the word
#   "axis", which refers to the x/y axis of a plot).

# %% [markdown]
# ### Examples
# I just want you to focus in the structure but not in the code. We will analyze the code soon

# %% [markdown]
# #### Object Oriented

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %% [markdown]
# #### Pyplot Style

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %% [markdown]
# * Matplotlib's documentation and examples use both the OO and the pyplot approaches (which are equally powerful)
# * Feel free to use either (however, it is preferable pick one of them and stick to it, instead of mixing them).
#
#
# * Suggest to restrict pyplot to interactive plotting (e.g., in a Jupyter notebook), and to prefer the OO-style for non-interactive plotting (in functions and scripts that are intended to be reused as part of a larger project).

# %% [markdown]
# # Parts of a Figure

# %% [markdown]
# <img src="anatomy.png" width="600">

# %% [markdown]
# The easiest way to create a new figure:

# %%
fig = plt.figure()  # an empty figure with no Axes
fig, ax = plt.subplots()  # a figure with a single Axes
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %% [markdown]
# ## Data
# We create some data that we want to plot

# %%
data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

# %% [markdown]
# ## We'll come back to this part  <--------

# %%
data
# Out:
# {'Barton LLC': 109438.5,
#  'Frami, Hills and Schmidt': 103569.59,
#  'Fritsch, Russel and Anderson': 112214.71,
#  'Jerde-Hilpert': 112591.43,
#  'Keeling LLC': 100934.3,
#  'Koepp Ltd': 103660.54,
#  'Kulas Inc': 137351.96,
#  'Trantow-Barrows': 123381.38,
#  'White-Trantow': 135841.99,
#  'Will LLC': 104437.6}

# %%
group_data
# Out:
# [109438.5,
#  103569.59,
#  112214.71,
#  112591.43,
#  100934.3,
#  103660.54,
#  137351.96,
#  123381.38,
#  135841.99,
#  104437.6]

# %%
group_names
# Out:
# ['Barton LLC',
#  'Frami, Hills and Schmidt',
#  'Fritsch, Russel and Anderson',
#  'Jerde-Hilpert',
#  'Keeling LLC',
#  'Koepp Ltd',
#  'Kulas Inc',
#  'Trantow-Barrows',
#  'White-Trantow',
#  'Will LLC']

# %%
group_mean
# Out:
# 114342.2

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data) #barh -> horizontal bar plot
# Out:
# <BarContainer object of 10 artists>
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
fig, ax = plt.subplots()
ax.bar(group_names, group_data) # bar -> vertical plot
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### To see different plot styles

# %%
print(plt.style.available)
# Out:
# ['seaborn-muted', 'seaborn-ticks', 'seaborn-colorblind', 'seaborn-poster', 'seaborn-talk', 'seaborn-dark', 'dark_background', 'seaborn-paper', 'bmh', 'seaborn-notebook', 'seaborn-pastel', 'classic', 'ggplot', 'seaborn-deep', 'Solarize_Light2', 'seaborn', '_classic_test', 'seaborn-darkgrid', 'grayscale', 'fast', 'seaborn-whitegrid', 'fivethirtyeight', 'seaborn-bright', 'tableau-colorblind10', 'seaborn-dark-palette', 'seaborn-white']

# %% [markdown]
# You can activate a style using this

# %%
plt.style.use('fivethirtyeight')

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# Now we've got a plot with the general look that we want, so let's fine-tune
# it so that it's ready for print. First let's rotate the labels on the x-axis
# so that they show up more clearly. We can gain access to these labels
# with the :meth:`axes.Axes.get_xticklabels` method:

# %%
plt.style.use('ggplot')

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# If we'd like to set the property of many items at once, it's useful to use
# the :func:`pyplot.setp` function. This will take a list (or many lists) of
# Matplotlib objects, and attempt to set some style element of each one.

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
plt.show()

# %%
plt.rcParams.update({'figure.autolayout': True})

fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# We can do this autolayout from the horizontal plot where x labels were stacked.

# %%
plt.rcParams.update({'figure.autolayout': True})

fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
#plt.setp(labels, rotation=45, horizontalalignment='right')
plt.show()

# %% [markdown]
# ### Labels

# %% [markdown]
# Next, we'll add labels to the plot. To do this with the OO interface,
# we can use the :meth:`axes.Axes.set` method to set properties of this
# Axes object.

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
plt.show()

# %% [markdown]
# ### Size

# %% [markdown]
# We can also adjust the size of this plot using the :func:`pyplot.subplots` function. We can do this with the ``figsize`` kwarg.

# %% [markdown]
# While indexing in NumPy follows the form (row, column), the figsize kwarg follows the form (width, height). This follows conventions in visualization, which unfortunately are different from those of linear algebra.

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')
ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
plt.show()

# %% [markdown]
# ### Changing the format of the labels

# %%
def currency(x, pos):
    """The two args are the value and tick position"""
    if x >= 1e6:
        s = '$'+str(int(x*1e-6))+'M'
    else:
        s = '$'+str(int(x*1e-3))+'K'
    return s

formatter = FuncFormatter(currency)

# %%
fig, ax = plt.subplots(figsize=(6, 8))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
ax.xaxis.set_major_formatter(formatter)

# %% [markdown]
# ## Combining multiple visualizations

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')

# Add a vertical line, here we set the style in the function call
ax.axvline(group_mean, ls='--', color='r')

# Annotate new companies
for group in [3, 5, 8]: # bottom up
    ax.text(145000, group, "New Company", fontsize=10,
            verticalalignment="center")

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')

# Now we'll move our title up since it's getting a little cramped
ax.title.set(y=1.05)

ax.xaxis.set_major_formatter(formatter) # do you remember the function we created before for the currency??

ax.set_xticks([0, 25e3, 50e3, 75e3, 100e3, 125e3]) # set the x axis labels
fig.subplots_adjust(right=.1)

plt.show()

# %% [markdown]
# ## Save our plot

# %% [markdown]
# There are many file formats we can save to in Matplotlib. To see a list of available options, use:

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'ps': 'Postscript', 'eps': 'Encapsulated Postscript', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format'}

# %%
fig.savefig('sales.png', transparent=False, dpi=80, bbox_inches="tight")

# %% [markdown]
# # Loading our image
#
# Click over the plot to see that I loaded the picture as a file, I'm not running code to generate it

# %% [markdown]
# <img src="sales.png" width="600">

# %% [markdown]
# ## This can get as complex as we want

# %%
df = pd.read_excel("https://github.com/chris1610/pbpython/blob/master/data/sample-salesv3.xlsx?raw=true")
df.head()
# Out:
#    account number                         name       sku  quantity  \
# 0          740150                   Barton LLC  B1-20000        39
# 1          714466              Trantow-Barrows  S2-77896        -1
# 2          218895                    Kulas Inc  B1-69924        23
# 3          307599  Kassulke, Ondricka and Metz  S1-65481        41
# 4          412290                Jerde-Hilpert  S2-34077         6
#
#    unit price  ext price                 date
# 0       86.69    3380.91  2014-01-01 07:21:51
# 1       63.16     -63.16  2014-01-01 10:00:47
# 2       90.70    2086.10  2014-01-01 13:24:58
# 3       21.05     863.05  2014-01-01 15:05:22
# 4       83.21     499.26  2014-01-01 23:26:55

# %% [markdown]
# Notice I used pd.read_excel this means that we **can read from excel spreadsheets**. Just be careful with combined cells

# %%
top_10 = (df.groupby('name')['ext price', 'quantity'].agg({'ext price': 'sum', 'quantity': 'count'})
          .sort_values(by='ext price', ascending=False))[:10].reset_index()
top_10
# Out:
#                            name  ext price  quantity
# 0                     Kulas Inc  137351.96        94
# 1                 White-Trantow  135841.99        86
# 2               Trantow-Barrows  123381.38        94
# 3                 Jerde-Hilpert  112591.43        89
# 4  Fritsch, Russel and Anderson  112214.71        81
# 5                    Barton LLC  109438.50        82
# 6                      Will LLC  104437.60        74
# 7                     Koepp Ltd  103660.54        82
# 8      Frami, Hills and Schmidt  103569.59        72
# 9                   Keeling LLC  100934.30        74

# %%
top_10.rename(columns={'name': 'Name', 'ext price': 'Sales', 'quantity': 'Purchases'}, inplace=True)
top_10
# Out:
#                            Name      Sales  Purchases
# 0                     Kulas Inc  137351.96         94
# 1                 White-Trantow  135841.99         86
# 2               Trantow-Barrows  123381.38         94
# 3                 Jerde-Hilpert  112591.43         89
# 4  Fritsch, Russel and Anderson  112214.71         81
# 5                    Barton LLC  109438.50         82
# 6                      Will LLC  104437.60         74
# 7                     Koepp Ltd  103660.54         82
# 8      Frami, Hills and Schmidt  103569.59         72
# 9                   Keeling LLC  100934.30         74

# %%
# Get the figure and the axes
fig, (ax0, ax1) = plt.subplots(nrows=1,ncols=2, sharey=True, figsize=(7, 4))

top_10.plot(kind='barh', y="Sales", x="Name", ax=ax0)

ax0.set_xlim([-10000, 140000])

ax0.set(title='Revenue', xlabel='Total Revenue', ylabel='Customers')

# Plot the average as a vertical line
avg = top_10['Sales'].mean()

ax0.axvline(x=avg, color='b', label='Average', linestyle='--', linewidth=1)

# Repeat for the unit plot
top_10.plot(kind='barh', y="Purchases", x="Name", ax=ax1)

avg = top_10['Purchases'].mean()

ax1.set(title='Units', xlabel='Total Units', ylabel='')

ax1.axvline(x=avg, color='b', label='Average', linestyle='--', linewidth=1)

# Title the figure
fig.suptitle('2014 Sales Analysis', fontsize=14, fontweight='bold',y=1.1,x=0.5);

# Hide the legends
ax1.legend().set_visible(False)

ax0.legend().set_visible(False)

plt.show()

# %% [markdown]
# <img src="matplot.png" width="900">

# %% [markdown]
# ## WAIT!!
# **So we spent an hour and a half learning pandas and now we don't use it???!!!**
#
# **False:** Pandas is a very convenient tool to work with because it allows us to clean the information, visualize it and then build our models.
#
# It is very important to understand data formatting, sometimes you will be asked to change data formats so that you can use certain libraries.

# %% [markdown]
# ### Let's try to do the same exercise but using pandas

# %% [markdown]
# First a series because the data has only one entry by every index, so we have to make it a series first. Don't blame me
#
#
# **Imagine you loaded your information this way into pandas**

# %%
data = pd.Series(data) 
data = pd.DataFrame(data)
data
# Out:
#                                       0
# Barton LLC                    109438.50
# Frami, Hills and Schmidt      103569.59
# Fritsch, Russel and Anderson  112214.71
# Jerde-Hilpert                 112591.43
# Keeling LLC                   100934.30
# Koepp Ltd                     103660.54
# Kulas Inc                     137351.96
# Trantow-Barrows               123381.38
# White-Trantow                 135841.99
# Will LLC                      104437.60

# %%
group_data = list(data.iloc[:,0])
group_names = list(data.index)
group_mean = data.iloc[:,0].mean()

# %%
group_data
# Out:
# [109438.5,
#  103569.59,
#  112214.71,
#  112591.43,
#  100934.3,
#  103660.54,
#  137351.96,
#  123381.38,
#  135841.99,
#  104437.6]

# %%
group_names
# Out:
# ['Barton LLC',
#  'Frami, Hills and Schmidt',
#  'Fritsch, Russel and Anderson',
#  'Jerde-Hilpert',
#  'Keeling LLC',
#  'Koepp Ltd',
#  'Kulas Inc',
#  'Trantow-Barrows',
#  'White-Trantow',
#  'Will LLC']

# %%
group_mean
# Out:
# 114342.2

# %% [markdown]
# **Now run all again from the part I wrote "We'll come back to this part"**

# %% [markdown]
# ## What about other types of plots??

# %% [markdown]
# [**MATPLOTLIB DOCUMENTATION**](https://matplotlib.org/gallery.html#lines_bars_and_markers)

# %% [markdown]
# # 2. SEABORN

# %% [markdown]
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# **In fewer words:** using matplotlib with cool designs and still being able to modify them.

# %% [markdown]
# For a brief introduction to the ideas behind the library, you can read the [introductory notes](https://seaborn.pydata.org/introduction.html). Visit the [installation page](https://seaborn.pydata.org/installing.html) to see how you can download the package. You can browse the [example gallery](https://seaborn.pydata.org/examples/index.html) to see what you can do with seaborn, and then check out the [tutorial](https://seaborn.pydata.org/tutorial.html) and [API reference](https://seaborn.pydata.org/api.html) to find out how.

# %%
import seaborn as sns

sns.set(style="white", context="talk")
rs = np.random.RandomState(8)

# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True) # define fig and axes (3)

# Generate some sequential data
x = np.array(list("ABCDEFGHIJ"))
y1 = np.arange(1, 11)
sns.barplot(x=x, y=y1, palette="rocket", ax=ax1)
ax1.axhline(0, color="k", clip_on=False)
ax1.set_ylabel("Sequential")

# Center the data to make it diverging
y2 = y1 - 5.5
sns.barplot(x=x, y=y2, palette="vlag", ax=ax2)
ax2.axhline(0, color="k", clip_on=False)
ax2.set_ylabel("Diverging")

# Randomly reorder the data to make it qualitative
y3 = rs.choice(y1, len(y1), replace=False)
sns.barplot(x=x, y=y3, palette="deep", ax=ax3)
ax3.axhline(0, color="k", clip_on=False)
ax3.set_ylabel("Qualitative")

# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=2)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/figure.py:2366: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# In a simple non-edited way

# %%
sns.set(style="white", context="talk")
rs = np.random.RandomState(8)

# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(7, 5), sharex=True) # define fig and axes (3)

sns.barplot(x=x, y=y1, palette="rocket", ax=ax1)

sns.barplot(x=x, y=y2, palette="vlag", ax=ax2)

sns.barplot(x=x, y=y3, palette="deep", ax=ax3)

plt.show()

# %% [markdown]
# # Open project_3

# %% [markdown]
# # REFERENCES
#
# [matplotlib](https://github.com/matplotlib)
